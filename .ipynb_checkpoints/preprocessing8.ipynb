# %%
from laonlp import word_tokenize
import pandas as pd

# %%
filename = pd.read_csv('..\Data\QnA.csv', header=None)

q = filename.iloc[:, 0].values
a = filename.iloc[:, 1].values

# %% [markdown]
# # Clean Question

# %%
question = []
questions = [word_tokenize(i) for i in q]
for i, tokens in enumerate(questions):
    for word in tokens:
        question.append(word)
print(question)
# Out:
# ['ສະບາຍດີ', 'ຂໍໂທດ', 'ຂອບໃຈ', 'ໃຜ', 'ເປັນ', 'ຫົວໜ້າ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ໃຜ', 'ເປັນ', 'ຮອງ', 'ຫົວໜ້າ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ສ້າງຂຶ້ນ', 'ໃນ', 'ປີ', 'ໃດ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ສາຂາ', 'ຫຍັງ', 'ແດ່', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ມີ', 'ຫຼັກສູດ', 'ປະລິນຍາເອກ', 'ບໍ', 'ມີ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທບໍ', 'ມີ', 'ຫຼັກສູດ', 'ຊັ້ນສູງ', 'ບໍ', 'ມີ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ປະລິນຍາ', 'ຕີບໍ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ປະລິນຍາເອກ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ປະລິນຍາ', 'ຕີ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ສາ
# ...

# %%
from collections import Counter

c = Counter(question)
len(c)
# Out:
# 159

# %%
items_to_remove = ['ສ້າງຂຶ້ນ','ວິຊາວິທະຍາສາດ','ໂທບໍ','ຕີບໍ','ໂທມີ','ສາຂາວິທະຍາສາດ','ສາຂາການພັດທະນາ','ຊ່ອງ','ທາງ',
                   'ໜ່ວຍ','ກິດ','ພາສາລາວ','ພາສາອັງກິດ','ຜູ້ຮັບຜິດຊອບ','ແລ້ວຈະ','ມີການສຳພາດ','ການສອບເສັງ','ການສຶກສາ',
                   'ມີການໄປ','ທັດສະນະສຶກສາບໍ','ຕີບໍ','ຈົບຊັ້ນສູງ','ຫາມື້ໃດ','ມື້ໃດ','ໂທສາຂາວິທະຍາສາດ','ບໍ່ສາມາດ','ການເຂົ້າ',
                   'ກຳນົດໄວ້','ເກ','ຣດ','ໂທສາຂາວິທະຍາ','ສາດ','ສາ','ວິຊາບັງຄັບ','ທາງການຕິດຕໍ່','ຈ່າຍຄ່າ','ຈົບຈາກ','ຄ່າທຳນຽມ',
                   'ນາໆຊາດ','ເຮັດແນວໃດ','ເຮັດ','ວຽກ','ຕາມທາງ','ປະລິນຍາ','ຕີ','ເອກ']
items_to_add = ['ວິທະຍາສາດ','ໂທ','ບໍ','ມີ','ສາຂາ','ວິທະຍາສາດ','ການ','ພັດທະນາ','ຊ່ອງທາງ','ໜ່ວຍກິດ',
                'ພາກຮຽນ','ແລ້ວ','ຈະ','ມີ','ການ','ສຳພາດ','ຄ່າ','ຮຽນ','ຄ່າ','ໜ່ວຍກິດ','ມີ','ການ','ໄປ','ທັດສະນະ','ສຶກສາ',
                'ບໍ','ຈົບ','ຊັ້ນສູງ','ຫາ','ມື້','ໃດ','ມື້','ໃດ','ໂທ','ສາຂາ','ສ້າງ','ຂຶ້ນ','ການ','ເຂົ້າ','ການ','ສອບເສັງ',
                'ວິທະຍາສາດ','ບໍ່','ສາມາດ','ກຳນົດ','ໄວ້','ເກຣດ','ວິຊາ','ບັງຄັບ','ທາງ','ການ','ຕິດຕໍ່','ປະລິນຍາໂທ',
                'ການ','ສຶກສາ','ຄ່າ','ທຳນຽມ','ນາໆ','ຊາດ','ເຮັດ','ແນວໃດ','ເຮັດ','ວຽກ','ຕາມ','ທາງ','ປະລິນຍາຕີ',]

question = [item for item in question if item not in items_to_remove]
question.extend(items_to_add)

print(len(question), question)
# Out:
# 6007 ['ສະບາຍດີ', 'ຂໍໂທດ', 'ຂອບໃຈ', 'ໃຜ', 'ເປັນ', 'ຫົວໜ້າ', 'ພາກ', 'ຄອມພິວເຕີ', 'ໃຜ', 'ເປັນ', 'ຮອງ', 'ຫົວໜ້າ', 'ພາກ', 'ຄອມພິວເຕີ', 'ພາກ', 'ຄອມພິວເຕີ', 'ໃນ', 'ປີ', 'ໃດ', 'ພາກ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ພາກ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ພາກ', 'ຄອມພິວເຕີ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ພາກ', 'ຄອມພິວເຕີ', 'ມີ', 'ສາຂາ', 'ຫຍັງ', 'ແດ່', 'ມີ', 'ຫຼັກສູດ', 'ປະລິນຍາເອກ', 'ບໍ', 'ມີ', 'ຫຼັກສູດ', 'ມີ', 'ຫຼັກສູດ', 'ຊັ້ນສູງ', 'ບໍ', 'ມີ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ຫຼັກສູດ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ປະລິນຍາເອກ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ມີ', 'ຈັກ', 'ສາຂາ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ຄອມພິວເຕີ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ໂປຣແກຣມ', 'ຄອມພິວເຕີ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ໂປຣແກຣມ', 'ຄອມພິວເຕີ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ເວັບໄຊ', 'ມີ', 'ຈັກ', 'ຫຼັກສູດ', 'ເວັບໄຊ', 'ມີ', 'ຫຼັກສູດ', 'ໃດ', 'ແດ່', 'ໃຜ', 'ເປັນ', 'ຄົນ', 'ຮັບຜິດຊອບ', 'ພາກ', 'ຄອມພິວເຕີ', 'ຊື່', 'ຫຼັກສູດ', 'ຂອງ',
# ...

# %% [markdown]
# # Qlean Answer

# %%
answer = []
answers = [word_tokenize(i) for i in a]
for i, tokens in enumerate(answers):
    for word in tokens:
        answer.append(word)
print(answer)
# Out:
# ['ສະບາຍດີ', ' ', 'ມີ', 'ຫຍັງ', 'ໃຫ້', 'ຊ່ວຍ', 'ບໍ', 'ບໍ່ເປັນຫຍັງ', 'ໂດຍ', ' ', 'ຍິນດີ', 'ທີ່', 'ໄດ້', 'ຊ່ວຍເຫຼືອ', 'ຫົວໜ້າ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ແມ່ນ', ' ', 'ອ', 'ຈ.ປ', 'ອ', '.', ' ', 'ລັດສະໝີ', ' ', 'ຈິດຕະ', 'ວົງ', 'ຮອງ', 'ຫົວໜ້າ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ແມ່ນ', ' ', 'ຊ', 'ອ', '.ປທ.', ' ', 'ອໍ', 'ລະດີ', ' ', 'ຄຳ', 'ມະນີ', 'ວົງ', ' ', 'ແລະ', ' ', 'ອ', 'ຈ.ປທ.', ' ', 'ອາ', 'ມອນ', ' ', 'ຈັນທະ', 'ພາວົງ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ສ້າງຂຶ້ນ', 'ໃນ', 'ສົກ', 'ປີ', ' ', '2004', '-', '2005', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ມີ', 'ທັງໝົດ', ' ', '3', ' ', 'ສາຂາ', 'ຄື', ':', ' ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', ',', ' ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', ' ', 'ແລະ', ' ', 'ສາຂາການພັດທະນາ', 'ໂປຣແກຣມ', 'ຄອມພິວເຕີ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ປະກອບ', 'ມີ', ' ', '3', ' ', 'ສາຂາ', 'ຄື', ':', ' ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', ',', ' ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', ' ', 'ແລະ', ' ', 'ສາຂາການພັດທະນາ', 'ໂປຣແກຣມ', 'ຄອມພິວເຕີ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວ
# ...

# %%
from collections import Counter

c = Counter(answer)
len(c)
# Out:
# 777

# %%
items_to_remove = ['ວິຊາວິທະຍາສາດ','ອ','ຈ.ປ','ອ','.','ຈິດຕະ','ວົງ','ຊ','ອ','.ປທ.','ອໍ','ລະດີ','ຄຳ','ມະນີ','ວົງ','ການກຳນົດ',
                   'ອ','ຈ.ປທ.','ອາ','ມອນ','ຈັນທະ','ພາວົງ','ສາຂາວິທະຍາສາດ','ສາຂາການພັດທະນາ','somsacki','ການຂຸດຄົ້ນ',
                   'ຍັງບໍ່ທັນ','ໂທມີ','ຊ່ອງ','ທາງ','cs','.','fns','@','nuol','.','edu','.','la','ການຂຽນ','ການຄັດເລືອກ',
                   'ຢາກຮູ້','ແລ້ວຈະ','ຄວາມຮູ້ຄວາມສາມາດ','ການນຳ','ວິທີການຄົ້ນຄວ້າ','ນັກ','ນັກ','ການຄຸ້ມຄອງ','ການທົດລອງ','ຕາມທາງ',
                   'ແລ້ວນຳ','ASP','CS','M','NET','Sc','VB','chidtavong','l','s','ຈົບຊັ້ນສູງ','ການທົດສອບ','ການນຳໃຊ້',
                   'thommaly','ກະຊວງສຶກສາທິການ','ການສຶກສາລະດັບ','ກຳນົດໄວ້','ກຳນົດໄວ້ແລ້ວຍື່ນ','ໜ່ວຍ','ກິດ','ກ່ຽວຂ້ອງກັບ',
                   'ຂັ້ນຕອນວິທີ','ຂ່າຍ','ຄະນະກຳມະການ','ຄະນະກຳມະການຢ່າງ','ຄະນະກຳມະການສອບເສັງ','ການບຳລຸງ','ການບໍລິຫານ','ເຮັດວຽກ',
                   'ຄ້ວາ','ຈຶ່ງມີການຮຽນ','ຈ່າຍຄ່າ','ຊອບແວດ້ວຍ','ຊີນ','ດາ','ຕາ','ຕາມາຍ','ດຳເນີນການພັດທະນາ','ດຳເນີນການສຶກສາ',
                   'ຕ່ຳກວ່າ','ຖືວ່າເປັນ','ຖ້າມີ','ທັດສະນະສຶກສາ','ທັດສະນະສຶກສານັກສຶກສາ','ທາງການຕິດຕໍ່','ທີ່ຈະ','ທີ່ມີ','ການປະຕິບັດ',
                   'ທີ່ມີການນຳໃຊ້','ທີ່ເສັງ','ນ','ນາ','ນິ່ງ','ນີ້ມີການຈັດຕັ້ງ','ບິກ','ບໍລິສັດທີ່ເຮັດວຽກ','ບໍ່ມີ','ບໍ່ມີການສຳພາດ','ບໍ່ມີການຮຽນ',
                   'ບໍ່ສາມາດ','ປັບ','ພື້ນຖານທີ່','ມະ','ມະນຸດສຳພັນ','ມາກ່ອນ','ມິງ','ມີການຄັດເລືອກ','ມີການສອນ','ມີການຮຽນ',
                   'ມີຄຸນສົມບັດ','ມີຄ່າ','ຣດ','ລ','ລວມເປັນ','ລະບຸລະອຽດ','ລະບົບປະຕິບັດການ','ລັບ','ວິຊາການຂຽນ','ວິຊາການທີ່',
                   'ວິຊາບັງຄັບ','ວິທະຍາສາດທຳມະຊາດ','ວິທີການຄົ້ນ','ວິທີການຮັກສາ','ວີ','ສາຂານີ້','ສາຂາມີ','ສາຂາວິຊາ','ສຶກສາກ່ຽວກັບ',
                   'ສຶກສາປ້ອງກັນ','ສົກ','ສ໌','ຫວັງດີດ້ວຍ','ຫາກວ່ານັກສຶກສາ','ອົງການຈັດຕັ້ງ','າ','ີ','ີນ','ເກ','ເຊນ','ເຊິ','ເຊີເວ',
                   'ເຕັກໂນໂລຊີດິຈິຕອນ','ເຕັກໂນໂລຊີບລັອກ','ເພື່ອການບໍລິຫານ','ເພື່ອນຳມາ','ເລ','ເລັກ','ເອ','ແຄ','ແຜນການຈັດຕັ້ງ',
                   'ແມ່','ແລ້ວຍື່ນ','ໂກ','ໂຄງການຈົບຊັ້ນ', 'ໂທນັ້ນ','ໂທນິກ','ໆ','\u200b','ໃນດ້ານ','ຣ','ນິກ','ຜູ້ຮັບຜິດຊອບ',
                   'ການປະມວນ', 'ການປະເມີນຜົນ','ການປ້ອງກັນ','ການພັດທະນາ','ການພິຈາລະນາ','ການຢັ້ງຢືນ','ການວັດ','ການວາງແຜນ',
                   'ການວິເຄາະ','ການວິໄຈ','ການສອນ','ການສອບເສັງ','ການສຳພາດ','ການສຶກສາ','ການສື່ສານ','ການສ້າງ','ການອອກແບບ',
                   'ການຮັບ','ການຮຽນ','ການຮຽນຮູ້','ການເຂົ້າ','ການເປັນ','ການເສຍ','ການເຮັດວຽກ','ການໂຈມຕີ','ການໄປ','ຈ່າຍເງິນ',
                   'ຂໍ້ມູນຂ່າວສານ','ຄວາມຊ່ຽວຊານ','ຄວາມຕ້ອງການ','ຄວາມປອດໄພ','ຄວາມແຕກຕ່າງກັນ','ຄຳຮ້ອງຂໍ','ຄ່າໃຊ້ຈ່າຍ','ສ້າງຂຶ້ນ',
                   'ນາໆຊາດ','ບໍ່ເປັນຫຍັງ','ບໍ່ໄດ້','ປະລິນຍາເອກ','ຜູ້ສຳເລັດ','ພາສາອັງກິດ','ມະຫາວິທະຍາໄລ','ລົງມາ','ວິທີການ','ບົດນຳ',
                   'ເຂົ້າມາ', 'ເຂົ້າໃນ','ເປັນຕົ້ນ','ເພາະວ່າ','ແກ້ບັນຫາ','ແຕກຕ່າງກັນ','ແມ່ນແລ້ວ','ແຫ່ງຊາດ','ໂທລະຄົມມະນາຄົມ',]

items_to_add = ['ວິທະຍາສາດ','ອຈ.','ປອ.','ຈິດຕະວົງ','ຊອ.','ປທ.','ອໍລະດີ','ຄຳມະນີວົງ','ອຈ.','ປທ.','ອາມອນ','ຈັນທະພາວົງ',
                'ສາຂາ','ວິທະຍາສາດ','ສາຂາ','ການ','ພັດທະນາ','ຍັງ','ບໍ່','ທັນ','ມີ','ຕອນນີ້','ການ','ທົດລອງ','ການ','ທົດສອບ',
                'ຊ່ອງທາງ','cs.fns@nuol.edu.la','ຢາກ','ຮູ້','ແລ້ວ','ຈະ','ຄວາມຮູ້','ຄວາມ','ສາມາດ','ການ','ນຳເອົາ','ການ','ນຳໃຊ້',
                'ວິທີ','ການ','ຄົ້ນຄວ້າ','ນັກຄົ້ນຄວ້າ','ນັກພັດທະນາ','ແລ້ວ','ນຳ','ASP.NET','M.Sc.CS','VB.NET','ການ','ຄຸ້ມຄອງ',
                'l.chidtavong@nuol.edu.la','s.thommaly@nuol.edu.la','somsacki@nuol.edu.la','ກະຊວງ','ສຶກສາ','ທິການ',
                'ການ','ສຶກສາ','ລະດັບ','ກຳນົດ','ໄວ້','ກຳນົດ','ໄວ້','ແລ້ວ','ຍື່ນ','ໜ່ວຍກິດ','ກ່ຽວຂ້ອງ','ກັບ','ຂັ້ນຕອນ','ວິທີ',
                'ຄະນະ','ກຳມະການ','ຄະນະ','ກຳມະການ','ຢ່າງ','ຄະນະ','ກຳມະການ','ສອບເສັງ','ຈຶ່ງ','ມີ','ການ','ຮຽນ','ຈ່າຍ','ຄ່າ',
                'ຊອບແວ','ດ້ວຍ','ດຳເນີນ','ການ','ພັດທະນາ','ດຳເນີນ','ການ','ສຶກສາ','ຕ່ຳ','ກວ່າ','ຖື','ວ່າ','ເປັນ','ຖ້າ','ມີ',
                'ທັດສະນະ','ສຶກສາ','ທັດສະນະ','ສຶກສາ','ນັກສຶກສາ','ການ','ຕິດຕໍ່','ທີ່','ຈະ','ທີ່','ມີ','ທີ່','ມີ','ການ','ນຳໃຊ້','ທີ່','ເສັງ',
                'ນີ້','ມີ','ການ','ຈັດຕັ້ງ','ບໍລິສັດ','ທີ່','ເຮັດ','ວຽກ','ບໍ່','ມີ','ບໍ່','ມີ','ການ','ສຳພາດ','ບໍ່','ມີ','ການ','ຮຽນ','ບໍ່','ສາມາດ',
                'ປັບ','ພື້ນຖານ','ທີ່','ມະນຸດ','ສຳພັນ','ມາ','ກ່ອນ','ມີ','ການ','ຄັດເລືອກ','ມີ','ການ','ສອນ','ມີ','ການ','ຮຽນ','ມີ',
                'ຄຸນສົມບັດ','ມີ','ຄ່າ','ລວມ','ເປັນ','ລະບຸ','ລະອຽດ','ລະບົບ','ປະຕິບັດການ','ວິຊາ','ການ','ຂຽນ','ວິຊາການ','ທີ່',
                'ວິຊາ','ບັງຄັບ','ວິທະຍາສາດ','ທຳມະຊາດ','ວິທີການ','ວິທີ','ການ','ຮັກສາ','ສາຂາ','ນີ້','ສາຂາ','ມີ','ສາຂາ','ວິຊາ',
                'ສຶກສາ','ກ່ຽວກັບ','ສຶກສາ','ປ້ອງກັນ','ຕົວ','ຫວັງດີ','ດ້ວຍ','ຫາກ','ວ່າ','ນັກສຶກສາ','ອົງການ','ຈັດຕັ້ງ','ເຕັກໂນໂລຊີ',
                'ດິຈິຕອນ','ເຕັກໂນໂລຊີ','ເພື່ອ','ການ','ບໍລິຫານ','ເພື່ອ','ນຳມາ','ແຜນການ','ຈັດຕັ້ງ','ແລ້ວ','ຍື່ນ','ໂຄງການ','ຈົບຊັ້ນ',
                'ໂທ','ນັ້ນ','ໃນ','ດ້ານ','ຜູ້','ຮັບຜິດຊອບ','ຈົບ','ຊັ້ນສູງ','ການ','ຂຸດຄົ້ນ','ການ','ຂຽນ','ການ','ຄັດເລືອກ',
                'ການ','ບຳລຸງ','ການ','ບໍລິຫານ','ການ','ປະຕິບັດ','ການ','ປະມວນ','ການ','ປະເມີນ','ຜົນ','ການ','ປ້ອງກັນ','ຕາມ','ທາງ',
                'ການ','ພັດທະນາ','ການ','ພິຈາລະນາ','ການ','ຢັ້ງຢືນ','ວັດ','ວາງແຜນ','ວິເຄາະ','ວິໄຈ','ສອນ','ສອບເສັງ','ສຳພາດ',
                'ສຶກສາ','ສື່ສານ','ສ້າງ','ອອກແບບ','ຮັບ','ຮຽນ','ຮຽນຮູ້','ເຂົ້າ','ເປັນ','ເສຍ','ເຮັດ','ວຽກ','ໂຈມຕີ','ໄປ',
                'ຂໍ້ມູນ','ຂ່າວສານ','ຄວາມ','ຊ່ຽວຊານ','ຕ້ອງການ','ປອດໄພ','ແຕກຕ່າງ','ກັນ','ຄຳຮ້ອງຂໍ','ຄຳຮ້ອງ','ຂໍ','ຄ່າ','ໃຊ້',
                'ຈ່າຍ','ເງິນ','ນາໆ','ຊາດ','ເປັນຫຍັງ','ບໍ່','ໄດ້','ຜູ້','ສຳເລັດ','ພາສາ','ອັງກິດ','ມະຫາ','ວິທະຍາໄລ','ລົງ','ມາ',
                'ວິທີ','ການ','ສ້າງ','ຂຶ້ນ','ເຂົ້າ','ມາ','ເຂົ້າ','ໃນ','ເປັນ','ຕົ້ນ','ເພາະ','ວ່າ','ແກ້','ບັນຫາ','ແຕກຕ່າງ','ກັນ',
                'ແມ່ນ','ແລ້ວ','ແຫ່ງ','ຊາດ','ໂທລະຄົມ','ມະນາຄົມ','ຕ່າງ','ປະເທດ','ບົດ','ນຳ','ເຮັດ','ວຽກ',]

answer = [item for item in answer if item not in items_to_remove]
answer.extend(items_to_add)

print(len(answer), answer)
# Out:
# 21290 ['ສະບາຍດີ', ' ', 'ມີ', 'ຫຍັງ', 'ໃຫ້', 'ຊ່ວຍ', 'ບໍ', 'ໂດຍ', ' ', 'ຍິນດີ', 'ທີ່', 'ໄດ້', 'ຊ່ວຍເຫຼືອ', 'ຫົວໜ້າ', 'ພາກ', 'ຄອມພິວເຕີ', 'ແມ່ນ', ' ', ' ', 'ລັດສະໝີ', ' ', 'ຮອງ', 'ຫົວໜ້າ', 'ພາກ', 'ຄອມພິວເຕີ', 'ແມ່ນ', ' ', ' ', ' ', ' ', 'ແລະ', ' ', ' ', ' ', 'ພາກ', 'ຄອມພິວເຕີ', 'ໃນ', 'ປີ', ' ', '2004', '-', '2005', 'ພາກ', 'ຄອມພິວເຕີ', 'ມີ', 'ທັງໝົດ', ' ', '3', ' ', 'ສາຂາ', 'ຄື', ':', ' ', 'ຄອມພິວເຕີ', ',', ' ', 'ເວັບໄຊ', ' ', 'ແລະ', ' ', 'ໂປຣແກຣມ', 'ຄອມພິວເຕີ', 'ພາກ', 'ຄອມພິວເຕີ', 'ປະກອບ', 'ມີ', ' ', '3', ' ', 'ຫຼັກສູດ', 'ຄື', ':', ' ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ປະລິນຍາ', 'ຕີ', ',', ' ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', ' ', 'ແລະ', ' ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທ', 'ພາກ', 'ຄອມພິວເຕີ', 'ປະກອບ', 'ມີ', 'ຫຼັກສູດ', 'ດັ່ງ', 'ນີ້', ':', ' ', 'ຫຼັກສູດ', 'ຕໍ່ເນື່ອງ', 'ປະລິນຍາ', 'ຕີ', ',', ' ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', ' ', 'ແລະ', ' ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທ', 'ພາກ', 'ຄອມພິວເຕີ', 'ປະກອບ', 'ມີ', ' ', '3', ' ', 'ສາຂາ', 'ຄື', ':', ' ', 'ຄອມພິວເຕີ', ',', ' ', 'ເວັບໄຊ', ' ', 'ແລະ', ' ', 'ໂປຣແກຣມ', 'ຄອ
# ...

# %% [markdown]
# # Save to Lao Corpus

# %%
words = {}
words = question + answer

# %%
grade = ['A+','B+','C+','D+','<PAD>','<EOS>','<OUT>','<SOS>']
for i in grade:
    words.append(i)

# %%
from collections import Counter
c = Counter(words)
print(len(c),c)
# Out:
# 677 Counter({' ': 6760, 'ຮຽນ': 1243, 'ຫຼັກສູດ': 1001, 'ຄອມພິວເຕີ': 948, 'ປີ': 788, 'ມີ': 680, ',': 640, 'ແມ່ນ': 574, '2': 516, 'ວິຊາ': 482, 'ພາກ': 479, 'ຂອງ': 451, '1': 443, 'ແລະ': 414, 'ປະລິນຍາ': 393, 'ຄ່າ': 355, 'ໂປຣແກຣມ': 334, 'ເວັບໄຊ': 313, 'ຕີ': 282, '(': 201, 'ຕໍ່ເນື່ອງ': 198, 'ໃດ': 189, 'ໂທ': 173, 'ໄດ້': 170, 'ລາຍ': 167, 'ໃນ': 161, '4': 159, 'ກີບ': 159, ':': 155, 'ຫຍັງ': 150, 'ເທົ່າໃດ': 137, 'ຈັກ': 128, 'ຈະ': 128, 'ຕ້ອງ': 128, 'ແດ່': 116, 'ຂໍ': 115, 'ກະລຸນາ': 115, '3': 113, 'ສຳລັບ': 107, 'ວ່າ': 106, ')': 106, 'ເບິ່ງ': 99, 'ດ້ວຍ': 94, 'ແຕ່ລະ': 89, '),': 89, 'ທັງໝົດ': 82, 'ປະກອບ': 79, 'ພາສາ': 78, 'ຕາມ': 78, 'ລວມ': 78, 'ສາຂາ': 73, 'ແນ່': 71, 'ທີ່': 71, 'ຊື່': 70, 'ວິທະຍາສາດ': 70, 'ລະບຸ': 68, 'ເຊິ່ງ': 68, 'ບໍ': 67, 'ໂດຍ': 67, 'ຂໍ້ມູນ': 67, 'ລະບົບ': 67, 'ຈົບ': 66, 'ຖ້າ': 66, 'ໂມງ': 66, 'ຈຳນວນ': 66, 'ຫຼື': 65, 'ພື້ນຖານ': 63, 'ເສຍ': 63, 'ເປັນ': 61, 'ໝວດ': 60, '-': 60, 'ສາມາດ': 56, 'ຫຼາຍ': 55, 'ຕໍ່': 53, 'ຫາ': 52, '/': 51, 'ສຶກສາ': 50, 'ການ': 48, '?': 48, 'ສະເພາະ': 47, 'ເຂົ້າ': 47, 'S
# ...

# %%
c = sorted(c)
print(c)
# Out:
# [' ', '#', '(', ')', '),', '+', '+)', '+),', '+,', ',', '-', '/', '0', '020', '021', '1', '1,220,000', '1,255,000', '1,290,000', '1,360,000', '1,570,000', '1,605,000', '1,640,000', '1,675,000', '1,710,000', '10', '100', '11.45', '11:30', '13.00', '137', '13:00', '14', '143', '144', '15', '15,950,000', '16.45', '16:30', '17', '173', '18', '19', '2', '2,860,000', '2.00', '2.50', '20', '2004', '2005', '21', '210,000', '22245128', '23232378', '25,300,000', '26', '27', '28', '29', '3', '3.0', '3.00', '30', '30,000', '310,000', '35,000', '36', '37', '38', '39', '4', '40', '46', '49', '5', '50', '54', '55', '550,000', '55682978', '55720450', '59', '6,035,000', '6,245,000', '6,280,000', '60', '64', '65', '69', '7', '70', '70,000', '74', '770', '77712077', '8', '8.00', '80', '81', '82', '8:00', '9', '9,350,000', '90', '91', ':', '<EOS>', '<OUT>', '<PAD>', '<SOS>', '=', '?', 'A', 'A+', 'AI', 'ASP.NET', 'Access', 'Advanced', 'Algorithms', 'App', 'Application', 'Artificial', 'B', 'B+', 'Bachelor
# ...

# %%
ignore = [' ', '#', '(', ')', '),', '+', '+)', '+),', '+,', ',', '-', '/', '0', '020', '021', '1', '1,220,000', '1,255,000', '1,290,000', '1,360,000', '1,570,000', '1,605,000', '1,640,000', '1,675,000', '1,710,000', '10', '100', '11.45', '11:30', '13.00', '137', '13:00', '14', '143', '144', '15', '15,950,000', '16.45', '16:30', '17', '173', '18', '19', '2', '2,860,000', '2.00', '2.50', '20', '2004', '2005', '21', '210,000', '22245128', '23232378', '25,300,000', '26', '27', '28', '29', '3', '3.0', '3.00', '30', '30,000', '310,000', '35,000', '36', '37', '38', '39', '4', '40', '46', '49', '5', '50', '54', '55', '550,000', '55682978', '55720450', '59', '6,035,000', '6,245,000', '6,280,000', '60', '64', '65', '69', '7', '70', '70,000', '74', '770', '77712077', '8', '8.00', '80', '81', '82', '8:00', '9', '9,350,000', '90', '91', ':', '=', '?']

# %%
file_name = "../lao_corpus.txt"

existing_items = set()

try:
    with open(file_name, 'r', encoding='utf-8') as file:
        for line in file:
            existing_items.add(line.strip())
except FileNotFoundError:
    pass

with open(file_name, 'a', encoding='utf-8') as file:
    for word in c:
        if word not in ignore:
            if word not in existing_items:
                file.write(word + '\n')
                existing_items.add(word) 

print("Save Successfully")
# Out:
# Save Successfully
