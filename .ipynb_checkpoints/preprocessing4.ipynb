# %%
from laonlp import word_tokenize
import re

# %%
filename = 'Data/master_cs1.txt'
cleaned_file = 'Cleaned_Data/cleaned_master_cs1.txt'

# %% [markdown]
# # Clean Data

# %%
def remove_special_characters(filename, cleanded_file):
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

    pattern = r'[^a-zA-Zກຂຄງຈສຊຍດຕຖທນບປຜຝພຟມຢລຫຼຣວຫອຮໜໝໆຽະາ ິ ີ ຶ ື ໂ ໍເແ ຸ ູຳໄໃ ັ ົ ່ ້ ໌]'
    clean_text = re.sub(pattern, '', text)

    with open(cleanded_file, 'w', encoding='utf-8') as file:
        file.write(clean_text)

remove_special_characters(filename, cleaned_file)


def delete_space(cleaned_file):
    with open(cleaned_file, 'r',encoding='utf-8') as file:
        content = file.read()

    modifile_content = content.replace(" ", "")        

    with open(cleaned_file, 'w', encoding='utf-8') as file:
        file.write(modifile_content)
        
delete_space(cleaned_file)

# %%
def delete_text_from_file(cleaned_file, text_to_delete):
    with open(cleaned_file, 'r',encoding='utf-8') as file:
        content = file.read()

    modified_content = content.replace(text_to_delete, '')

    with open(cleaned_file, 'w', encoding='utf-8') as file:
        file.write(modified_content)

text_to_delete = "MPOLແນວທາງການເມືອງຂອງສປປລາວPoliticalPoliciesofLaosMDSAໂຄງສ້າງຂໍ້ມູນແລະຂັ້ນຕອນວິທີDataStructureandComputerAlgorithmMAAIປັນຍາປະດິດລະດັບສູງAdvancedartificialintelligenceລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດMRMCວິທີການຄົ້ນຄ້ວາທາງວິທະຍາສາດຄອມພິວເຕີResearchMethodologyInComputerScienceMDAMດາຕາມາຍນິ່ງDataMiningMMCSຄະນິດສາດສຳລັບຄອມພິວເຕີMathematicsforComputerScienceລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດxxxxxວິຊາເລືອກxxxxxວິຊາເລືອກMDASວິທະຍາສາດຂໍ້ມູນDataScienceMCGVຄອມພິວເຕີກຣາຟຟິກແລະວີເຊິນComputerGraphicsandVisionລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດMMALມາຊີນເລີນນິ່ງMachineLearningMOPSລະບົບປະຕິບັດການOperatingSystemMTHSວິທະຍານິພົນThesisລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດMREEການທົດລອງແລະການປະເມີນຜົນການວິໄຈResearchExperimentandEvaluationMBIDບິກດາຕາBigDataMTHSວິທະຍານິພົນThesisລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດMTHSວິທະຍານິພົນThesisລວມ"
delete_text_from_file(cleaned_file, text_to_delete)

# %% [markdown]
# # Word Tokenize

# %%
with open(cleaned_file, encoding='utf-8') as file:
    content = file.read()
    words = word_tokenize(content)
print(len(words), words)
# Out:
# 667 ['ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທ', 'ວິທະຍາສາດ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຊື່', 'ຫຼັກສູດ', 'ຊື່', 'ພາສາລາວ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທ', 'ວິທະຍາສາດ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຊື່', 'ພາສາອັງກິດ', 'MasterofSciencePrograminComputerScience', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ຊື່', 'ພາສາລາວ', 'ປະລິນຍາ', 'ໂທ', 'ວິທະຍາສາດ', 'ສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຊື່', 'ຫຍໍ້', 'ພາສາລາວ', 'ປທວຄ', 'ຊື່', 'ເຕັມ', 'ພາສາອັງກິດ', 'MasterofScienceinComputerScience', 'ຊື່', 'ຫຍໍ້', 'ພາສາອັງກິດ', 'MSc', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ຄະນະ', 'ວິທະຍາສາດທຳມະຊາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ພະແນກ', 'ການສຶກສາ', 'ຫຼັງ', 'ປະລິນຍາ', 'ຕີ', 'ໂທລະສັບ', 'ແ', 'ຟັກ', 'ອີເມວ', 'bounphanhtongmailcom', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ວິທະຍາສາດທຳມະຊາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ອີເມວ', 'somsackinuoledulalchidtavongnuoledula', 'ປັດຊະຍາ', 'ແລະ', 'ຈຸດປະສົງ', 'ຂອງ', 'ຫຼັກສູດ', 'ປັດຊະຍາ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ໂທສາຂາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ສ້າງຂຶ້ນ', 'ບົນ', 'ພື້ນຖານ', 'ລັກສະນະ', 'ຫຼັກ', 'ມູນ', 'ຕາມ', 'ນະໂຍບາຍ', 'ຂອງ
# ...

# %% [markdown]
# # Re-Clean Data

# %%
split_values = ['MasterofSciencePrograminComputerScience','MasterofScienceinComputerScience','MSc',
                'bounphanhtongmailcom','somsackinuoledulalchidtavongnuoledula','MotivationLetter',
                'ສາຂາວິທະຍາສາດ','ປທວຄ','ວິທະຍາສາດທຳມະຊາດ','ວິຊາວິທະຍາສາດ','ໂທສາຂາວິທະຍາສາດ','ກະຊວງສຶກສາທິການ',
                'ໃຫ້ມີຄຸນນະທຳ','ນັກວິຊາການໃຫ້ມີ','ວິທີການຄົ້ນຄວ້າ','ສາຂາວິຊາວິທະຍາສາດ','ການກຳນົດການເປີດ','ດຳເນີນການຮຽນ',
                'ນັກສຶກສາປີ','ມີນັກສຶກສາ','ບໍ່ສາມາດ','ປະສົບການເຮັດວຽກ','ໄປນອກຈາກ','ກຳນົດໄວ້ແລ້ວນັ້ນ','ວິທີການເລືອກ',
                'ກິລາວິທີການເລືອກ','ທີ່ມີມາດຖານ','ຖືກຕ້ອງຕາມ','ກຳນົດໄວ້','ໂທເລກທີ','ມີການຮຽນ','ທິດສະດີການຮຽນ','ທັດສະນະສຶກສາ',
                'ເວລາການສຶກສາການຮຽນ','ແຕ່ລະພາກ','ວິຊາບັງຄັບ','ພື້ນຖານທີ່','ຈຳເປັນແຕ່','ແຜນການຮຽນ','ທີ່ຈະ', 'ທີ່ເປັນ', 'ທີ່ໃຊ້',
                'ແລ້ວນັກສຶກສາ','ສະແດງວ່າ','ໃນດ້ານ']

items_to_insert = [['Master', 'of','Science','Program','in','Computer','Science'],
                   ['Master', 'of','Science','in','Computer','Science'],['M.Sc.'],['bounphanh.ton@gmail.com'],
                   ['somsacki@nuol.edu.la','l.chidtavong@nuol.edu.la'],['Motivation','Letter'],['ສາຂາ','ວິທະຍາສາດ'],
                   ['ປທ.ວຄ.'],['ວິທະຍາສາດ','ທຳມະຊາດ'],['ວິຊາ','ວິທະຍາສາດ'],['ໂທ','ສາຂາ','ວິທະຍາສາດ'],['ກະຊວງ','ສຶກສາທິການ'],
                   ['ໃຫ້','ມີ','ຄຸນນະທຳ'],['ນັກວິຊາການ','ໃຫ້','ມີ'],['ວິທີ','ການຄົ້ນຄວ້າ'],['ສາຂາ','ວິຊາ','ວິທະຍາສາດ'],
                   ['ການກຳນົດ','ການເປີດ'],['ດຳເນີນ','ການຮຽນ'],['ນັກສຶກສາ','ປີ'],['ມີ','ນັກສຶກສາ'],['ບໍ່','ສາມາດ'],
                   ['ປະສົບການ','ເຮັດວຽກ'],['ໄປ','ນອກຈາກ'],['ກຳນົດ','ໄວ້','ແລ້ວ','ນັ້ນ'],['ວິທີ','ການເລືອກ'],
                   ['ກິລາ','ວິທີ','ການເລືອກ'],['ທີ່','ມີ','ມາດຖານ'],['ຖືກຕ້ອງ','ຕາມ'],['ກຳນົດ','ໄວ້'],['ໂທ','ເລກທີ'],
                   ['ມີ','ການຮຽນ'],['ທິດສະດີ','ການຮຽນ'],['ທັດສະນະ','ສຶກສາ'],['ເວລາ','ການສຶກສາ','ການຮຽນ'],
                   ['ແຕ່ລະ','ພາກ'],['ວິຊາ','ບັງຄັບ'],['ພື້ນຖານ','ທີ່'],['ຈຳເປັນ','ແຕ່'],['ແຜນ','ການຮຽນ'],['ທີ່','ຈະ'],
                   ['ທີ່','ເປັນ'],['ທີ່','ໃຊ້'],['ແລ້ວ','ນັກສຶກສາ'],['ສະແດງ','ວ່າ'],['ໃນ','ດ້ານ']]

for split_value, items in zip(split_values, items_to_insert):
    index = 0
    while index < len(words):
        if words[index] == split_value:
            # Insert the items after the split value
            for item in items:
                words.insert(index + 1, item)
            # Move index past the newly inserted items
            index += len(items)
            words.remove(split_value)
        else:
            index += 1

# %%
items_to_remove = ['ປະລິນຍາ', 'ໂທ','ຕີ','ແ', 'ຟັກ','ຫຼັກ','ມູນ','ຄວາມ','ນັກ','ໆ','ຈາ', 'ລິ', 'ຍະທຳ','ສົກ','ໆ','ອີງ',
                   'ສສ', 'ຊສ','ໜ່ວຍ','ກິດ']
items_to_add = ['ປະລິນຍາໂທ', 'ປະລິນຍາຕີ','ແຟັກ','ຫຼັກມູນ','ຄວາມຮຽກຮ້ອງ','ນັກຄົ້ນຄວ້າ','ໃໝ່ໆ','ຈະລິຍະທຳ','ສົກສຶກສາ','ສົກຮຽນ',
                'ຕໍ່ໆ','ອີງຕາມ','ດັ່ງນີ້','ສສ.ຊສ','ໜ່ວຍກິດ','ແກ່ຍາວ']

words = [item for item in words if item not in items_to_remove]
words.extend(items_to_add)
print(len(words), words)
# Out:
# 698 ['ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ວິທະຍາສາດ', 'ສາຂາ', 'ຄອມພິວເຕີ', 'ຊື່', 'ຫຼັກສູດ', 'ຊື່', 'ພາສາລາວ', 'ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ວິທະຍາສາດ', 'ສາຂາ', 'ຄອມພິວເຕີ', 'ຊື່', 'ພາສາອັງກິດ', 'Science', 'Computer', 'in', 'Program', 'Science', 'of', 'Master', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ຊື່', 'ພາສາລາວ', 'ວິທະຍາສາດ', 'ວິທະຍາສາດ', 'ສາຂາ', 'ຄອມພິວເຕີ', 'ຊື່', 'ຫຍໍ້', 'ພາສາລາວ', 'ປທ.ວຄ.', 'ຊື່', 'ເຕັມ', 'ພາສາອັງກິດ', 'Science', 'Computer', 'in', 'Science', 'of', 'Master', 'ຊື່', 'ຫຍໍ້', 'ພາສາອັງກິດ', 'M.Sc.', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ຄະນະ', 'ທຳມະຊາດ', 'ວິທະຍາສາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ພະແນກ', 'ການສຶກສາ', 'ຫຼັງ', 'ໂທລະສັບ', 'ອີເມວ', 'bounphanh.ton@gmail.com', 'ພາກ', 'ວິທະຍາສາດ', 'ວິຊາ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ທຳມະຊາດ', 'ວິທະຍາສາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ອີເມວ', 'l.chidtavong@nuol.edu.la', 'somsacki@nuol.edu.la', 'ປັດຊະຍາ', 'ແລະ', 'ຈຸດປະສົງ', 'ຂອງ', 'ຫຼັກສູດ', 'ປັດຊະຍາ', 'ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ສາຂາ', 'ຄອມພິວເຕີ', 'ສ້າງຂຶ້ນ', 'ບົນ', 'ພື້ນຖານ', 'ລັກສະນະ', 'ຕາມ', 'ນະໂຍບາຍ', 'ຂອງ', 'ສຶກສາທິການ', '
# ...

# %% [markdown]
# # Save to Lao Corpus

# %%
from collections import Counter
c = Counter(words)
print(len(c),c)
# Out:
# 296 Counter({'ວິທະຍາສາດ': 20, 'ແລະ': 20, 'ໃນ': 18, 'ທີ່': 16, 'ຄອມພິວເຕີ': 15, 'ຫຼັກສູດ': 14, 'ມີ': 14, 'ຮຽນ': 13, 'ວິຊາ': 10, 'ຕາມ': 10, 'ນັກສຶກສາ': 10, 'ສາຂາ': 9, 'ຊື່': 9, 'ການຮຽນ': 9, 'ປີ': 9, 'ຂອງ': 8, 'ຫຼື': 8, 'ແມ່ນ': 8, 'ຈະ': 7, 'ຈຳນວນ': 7, 'ພາກ': 6, 'ລະດັບ': 6, 'ໄປ': 6, 'ຕ່າງໆ': 6, 'ໄດ້': 6, 'ຕ້ອງ': 6, 'ພາສາອັງກິດ': 5, 'ແຫ່ງຊາດ': 5, 'ເພື່ອ': 5, 'ໃຫ້': 5, 'ການສອນ': 5, 'ເວລາ': 5, 'ສຶກສາ': 5, 'ກຳນົດ': 5, 'ພາສາລາວ': 4, 'Science': 4, 'ການສຶກສາ': 4, 'ສັງຄົມ': 4, 'ເປັນ': 4, 'ດ້ານ': 4, 'ແບບ': 4, 'ຈົບ': 4, 'ບໍ່': 4, 'ຮັບ': 4, 'ຜູ້': 4, 'ຂຶ້ນ': 4, 'ໝວດ': 4, 'ເຕັມ': 3, 'ມະຫາວິທະຍາໄລ': 3, 'ຈຸດປະສົງ': 3, 'ການພັດທະນາ': 3, 'ລະບົບ': 3, 'ສ້າງ': 3, 'ສາມາດ': 3, 'ຄວາມຮູ້': 3, 'ຕໍ່': 3, 'ຊອບແວ': 3, 'ສອນ': 3, 'ນີ້': 3, 'ຮູບແບບ': 3, 'ເຂົ້າ': 3, 'ຖ້າ': 3, 'ນອກຈາກ': 3, 'ໄວ້': 3, 'ທີ': 3, 'ໃຊ້': 3, 'ອາທິດ': 3, 'Computer': 2, 'in': 2, 'of': 2, 'Master': 2, 'ຫຍໍ້': 2, 'ຄະນະ': 2, 'ທຳມະຊາດ': 2, 'ອີເມວ': 2, 'ປັດຊະຍາ': 2, 'ພື້ນຖານ': 2, 'ສຶກສາທິການ': 2, 'ກະຊວງ': 2, 'ກິລາ': 2, 'ເຮັດວຽກ': 2, 'ທີມງານ': 2, 'ບໍລ
# ...

# %%
c = sorted(c)
print(c)
# Out:
# ['CGPA', 'Computer', 'Letter', 'M.Sc.', 'Master', 'Motivation', 'Program', 'Science', 'Software', 'bounphanh.ton@gmail.com', 'in', 'l.chidtavong@nuol.edu.la', 'of', 'somsacki@nuol.edu.la', 'ກະຊວງ', 'ກັບ', 'ກາງ', 'ການ', 'ການກຳນົດ', 'ການຄົ້ນຄວ້າ', 'ການຈັດຕັ້ງ', 'ການປະດິດ', 'ການພັດທະນາ', 'ການສອນ', 'ການສຶກສາ', 'ການສ້າງ', 'ການຮຽນ', 'ການເປີດ', 'ການເລືອກ', 'ການເຮັດວຽກ', 'ການແກ້ບັນຫາ', 'ການແກ້ໄຂ', 'ກຳນົດ', 'ກິລາ', 'ກ່ຽວກັບ', 'ກ່ຽວຂ້ອງ', 'ກໍ່', 'ຂອງ', 'ຂຶ້ນ', 'ຂຽນ', 'ຂ່າວສານ', 'ຂ້າງ', 'ຂໍ້', 'ຂໍ້ຕົກລົງ', 'ຂໍ້ມູນ', 'ຄວາມຕ້ອງການ', 'ຄວາມຜູກພັນ', 'ຄວາມສາມາດ', 'ຄວາມຮັບຜິດຊອບ', 'ຄວາມຮູ້', 'ຄວາມຮຽກຮ້ອງ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ຄະນິດສາດ', 'ຄະແນນ', 'ຄາດຄະເນ', 'ຄື', 'ຄຸນນະທຳ', 'ຄຸນນະພາບ', 'ຄຸນສົມບັດ', 'ຄົນ', 'ຄົບຖ້ວນ', 'ຄົ້ນຄວ້າ', 'ຈະ', 'ຈະລິຍະທຳ', 'ຈັນຍາບັນ', 'ຈາກ', 'ຈຳນວນ', 'ຈຳລອງ', 'ຈຳເປັນ', 'ຈຸດປະສົງ', 'ຈົດໝາຍ', 'ຈົບ', 'ຊອບແວ', 'ຊື່', 'ຊົ່ວໂມງ', 'ຍັງ', 'ຍາວ', 'ດັ່ງ', 'ດັ່ງນີ້', 'ດຳເນີນ', 'ດ້ານ', 'ຕອນບ່າຍ', 'ຕອນເຊົ້າ', 'ຕອບສະໜອງ', 'ຕະຫຼາດ', 'ຕາຕະລາງ', 'ຕາມ', 'ຕື່ມ', 'ຕົນເອງ', 'ຕົວຈິງ', 'ຕ່າງປະເທດ', '
# ...

# %%
file_name = "corpus.txt"

existing_items = set()

# Read existing items from the file
try:
    with open(file_name, 'r', encoding='utf-8') as file:
        for line in file:
            # Remove newline characters and add to the set
            existing_items.add(line.strip())
except FileNotFoundError:
    # If the file does not exist, continue as there are no existing items
    pass

with open(file_name, 'a', encoding='utf-8') as file:
    for word in c:
        if word not in existing_items:
            file.write(word + '\n')
            existing_items.add(word)  

print("save successfully")
# Out:
# save successfully

# %% [markdown]
# # Add Subject

# %%
subject_code = ['251MPOL1','251MDSA2','251MAAI2','251MRMC1','251MDAM3','251MMCS3','251xxxxx','251MDAS4',
                '251MCGV3','251MMAL3','251MOPS3','251MTHS5','251MREE3','251MBID4']
subject_lao = ['ແນວທາງການເມືອງ','ຂອງ','ສປປ','ລາວ','ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນວິທີ','ປັນຍາ','ປະດິດ','ລະດັບ','ສູງ',
               'ວິທີການຄົ້ນຄວ້າ','ທາງ','ວິທະຍາສາດ','ຄອມພິວເຕີ','ດາຕາມາຍນິ່ງ','ຄະນິດສາດ','ສຳລັບ','ຄອມພິວເຕີ','ວິທະຍາສາດ',
               'ຂໍ້ມູນ','ຄອມພິວເຕີ','ກຣາຟຟິກ','ແລະ','ວີເຊິນ','ມາຊີນເລີນນິ່ງ','ລະບົບປະຕິບັດການ','ວິທະຍານິພົນ','ການທົດລອງ',
               'ແລະ','ການປະເມີນຜົນ','ການວິໄຈ','ບິກ','ດາຕາ']
subject_eng = ['Research','Methodology','In','Computer','Science','Data','Mining','Mathematics','for','Computer',
                'Science','Data','Science','Computer','Graphics','and','Vision','Machine','Learning','Operating',
                'System','Thesis','Research','Experiment','and','Evaluation','Big','Data']
