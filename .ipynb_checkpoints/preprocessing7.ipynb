# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('Data/subjects.csv')
file
# Out:
#      ລາຍວິຊາຮຽນ 2023-2024  Unnamed: 1           Unnamed: 2 Unnamed: 3  \
# 0                     1.0    115LS101            ລາວສຶກສາ1   2(2-0-4)
# 1                     2.0    145PY101  ຈິດຕະວິທະຍາ​ທົ່ວ​ໄປ   2(2-0-4)
# 2                     3.0   205BI111x    ພື້ນຖານຊີວະວິທະຍາ   3(2-2-5)
# 3                     4.0    205CA111       ​ແຄລຄູ​ລັດສ໌ 1   3(2-2-5)
# 4                     5.0    205CH111            ເຄມີສາດ 1   3(3-0-6)
# ..                    ...         ...                  ...        ...
# 740                 761.0  205ML221xx    ທົດລອງອີເລກໂທຣນິກ   1(0-3-1)
# 741                 762.0   205AP221x           ຟີຊິກອາຕອມ   3(2-2-5)
# 742                 763.0   205AL221x     ທົດລອງຟີຊິກອາຕອມ   1(0-3-1)
# 743                 764.0    205PP212  ໂປຣແກຣມສຳລັບຟິຊິກ2    2(1-2-3)
# 744                 765.0    205ND201      ສຶກສາປ້ອງກັນຕົວ   3(0-6-3)
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# ...

# %%
ccs = file.iloc[99:123,1].values
ccs
# Out:
# array(['204AD121', '204DS121', '204MB111', '204MI101', '204OO111',
#        '204OS111', '204RE301', '204CN111', '204DB111', '204DD121',
#        '204DM121', '204MC101', '204SA121', '204CR221', '204DA221',
#        '204RC221', '204SC211', '204SE221', '204WP221', '204WS221',
#        '204AI211', '204CS211', '204FP221', '204LN231'], dtype=object)

# %%
cs = file.iloc[255:416,1].values
cs
# Out:
# array(['115LS101', '145PY101', '205CF111', '205CP111', '205CS111x',
#        '205DB111', '205ES101', '135LS102', '205CN121', '205DB112x',
#        '205ES102', '205FS111', '205JA121', '205MC111', '205AD221xx',
#        '205LN221', '205SH221', '205EC203x', '205UX211', '205JA222',
#        '205WS211', '205EC102', '205IM221', '205SH322x', '205MO211',
#        '205ND201', '205OD221xxx', '205AD222x', '205DM221', '205LN321',
#        '205OS311', '205RM311x', '205SH321', '205VB322', '205WT321',
#        '205AP331', '205SA321', '205SC321', '205SE311', '205SH322',
#        '205WS311', 'S20HR223', '251AI411', '251DI321', '251MI221',
#        '251SM422', '252LS421', '252PM421', '710GE328', 'S00PO101',
#        '252IP431', '252PJ431', '115LS101', '145PY101', '205BC121',
#        '205CP111', '205CS121', '205DB111', '205ES101', '205MC111',
#        '135LS102', '205CA111', '205DB122', '205ES102', '205FS111',
#        '205OS121', '205PY121', '205AD221', '205CA112', '205DS221',
# ...

# %%
subject_code = np.concatenate((ccs,cs))
subject_code
# Out:
# array(['204AD121', '204DS121', '204MB111', '204MI101', '204OO111',
#        '204OS111', '204RE301', '204CN111', '204DB111', '204DD121',
#        '204DM121', '204MC101', '204SA121', '204CR221', '204DA221',
#        '204RC221', '204SC211', '204SE221', '204WP221', '204WS221',
#        '204AI211', '204CS211', '204FP221', '204LN231', '115LS101',
#        '145PY101', '205CF111', '205CP111', '205CS111x', '205DB111',
#        '205ES101', '135LS102', '205CN121', '205DB112x', '205ES102',
#        '205FS111', '205JA121', '205MC111', '205AD221xx', '205LN221',
#        '205SH221', '205EC203x', '205UX211', '205JA222', '205WS211',
#        '205EC102', '205IM221', '205SH322x', '205MO211', '205ND201',
#        '205OD221xxx', '205AD222x', '205DM221', '205LN321', '205OS311',
#        '205RM311x', '205SH321', '205VB322', '205WT321', '205AP331',
#        '205SA321', '205SC321', '205SE311', '205SH322', '205WS311',
#        'S20HR223', '251AI411', '251DI321', '251MI221', '251SM422',
# ...

# %%
ccs_name = file.iloc[99:123,2].values
ccs_name
# Out:
# array(['ໂຄງສ້າງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ', 'Data Science',
#        'ການຂຽນໂປຣແກຣມສໍາລັບມືຖື', 'ລະບົບຂ່າວສານເພື່ອການບໍລິຫານ',
#        'ການພັດທະນາລະບົບດ້ວຍຮູບແບບວັັດຖຸ', 'ລະບົບປະຕິບັດການ', 'ສະຖິຕິວິໄຈ',
#        'ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ', 'ລະບົບຖານຂໍ້ມູນ',
#        'Desktop Application Development',
#        'ການຂຸດຄົົ້ນຂໍ້ມູນ (Data Mining)', 'Mathematics for Computing',
#        'ການວິເຄາະ ແລະ ອອກແບບລະບົບ', 'ການສ້າງລາຍງານດ້ວຍ Crystal Report',
#        'ການຄຸູ້ມຄອງຖານຂໍ້ມູນ', 'ວິທີການຄົ້ນຄວ້າ', 'ສໍາມະນາ',
#        'ວິສະວະກໍາຊອບແວ', 'Web Programming', 'Web Server and Technology',
#        'ປັນຍາປະດິດ', 'ຄວາມປອດໄພ ແລະ ຈັນຍາບັນການນາໃຊ້ຄອມພິວເຕີ',
#        'ໂຄງການຈົບຊັ້ນ', 'ການຄ້າດ້ວຍເອເລັກໂທນິກ'], dtype=object)

# %%
cs_name = file.iloc[255:416,2].values
cs_name
# Out:
# array(['ລາວສຶກສາ1', 'ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ', 'ຄອມພີວເຕີພື້ນຖານ',
#        'ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມດ້ວຍ\u200bພາສາ C',
#        'ລະບົບ\u200bຄອມ\u200bພິວ\u200bເຕີ',
#        'ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200bຖານ\u200bຂໍ້\u200bມູນ(MS Access)',
#        'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ 1', 'ລາວ\u200bສຶກສາ2',
#        'ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ', 'ລະບົບຖານຂໍ້ມູນແບບໂຄງສ້າງ',
#        'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ2', 'ສະຖິຕິ\u200bພື້ນຖານ',
#        '\u200bພາສາໂປຣ\u200bແກຣມ1(Java1)',
#        'ຄະນິດສາດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1',
#        '\u200bໂຄງ\u200bສ້າງ\u200bຂໍ້\u200bມູນ \u200bແລະ ຂັ້ນ\u200bຕອນ\u200bວິທີ',
#        'ພື້ນຖານການບໍລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Linux',
#        'ການຂຽນໂປຣແກຣມດ້ວຍພາສາ C# 1',
#        'ພາສາ\u200bອັງກິດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1',
#        'ການອ\u200bອກ\u200bແບບ UX-UI', 'ພາສາໂປຣ\u200bແກຣມ2(Java2)',
#        'ພື້ນຖານການບໍລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Window',
# ...

# %%
subject_name = np.concatenate((ccs_name, cs_name))
subject_name
# Out:
# array(['ໂຄງສ້າງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ', 'Data Science',
#        'ການຂຽນໂປຣແກຣມສໍາລັບມືຖື', 'ລະບົບຂ່າວສານເພື່ອການບໍລິຫານ',
#        'ການພັດທະນາລະບົບດ້ວຍຮູບແບບວັັດຖຸ', 'ລະບົບປະຕິບັດການ', 'ສະຖິຕິວິໄຈ',
#        'ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ', 'ລະບົບຖານຂໍ້ມູນ',
#        'Desktop Application Development',
#        'ການຂຸດຄົົ້ນຂໍ້ມູນ (Data Mining)', 'Mathematics for Computing',
#        'ການວິເຄາະ ແລະ ອອກແບບລະບົບ', 'ການສ້າງລາຍງານດ້ວຍ Crystal Report',
#        'ການຄຸູ້ມຄອງຖານຂໍ້ມູນ', 'ວິທີການຄົ້ນຄວ້າ', 'ສໍາມະນາ',
#        'ວິສະວະກໍາຊອບແວ', 'Web Programming', 'Web Server and Technology',
#        'ປັນຍາປະດິດ', 'ຄວາມປອດໄພ ແລະ ຈັນຍາບັນການນາໃຊ້ຄອມພິວເຕີ',
#        'ໂຄງການຈົບຊັ້ນ', 'ການຄ້າດ້ວຍເອເລັກໂທນິກ', 'ລາວສຶກສາ1',
#        'ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ', 'ຄອມພີວເຕີພື້ນຖານ',
#        'ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມດ້ວຍ\u200bພາສາ C',
#        'ລະບົບ\u200bຄອມ\u200bພິວ\u200bເຕີ',
#        'ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200bຖານ\u200bຂໍ້\u200bມູນ(MS Access)',
# ...

# %%
words = []
for word in subject_code:
    words.append(word)

print(len(words), words)
# Out:
# 185 ['204AD121', '204DS121', '204MB111', '204MI101', '204OO111', '204OS111', '204RE301', '204CN111', '204DB111', '204DD121', '204DM121', '204MC101', '204SA121', '204CR221', '204DA221', '204RC221', '204SC211', '204SE221', '204WP221', '204WS221', '204AI211', '204CS211', '204FP221', '204LN231', '115LS101', '145PY101', '205CF111', '205CP111', '205CS111x', '205DB111', '205ES101', '135LS102', '205CN121', '205DB112x', '205ES102', '205FS111', '205JA121', '205MC111', '205AD221xx', '205LN221', '205SH221', '205EC203x', '205UX211', '205JA222', '205WS211', '205EC102', '205IM221', '205SH322x', '205MO211', '205ND201', '205OD221xxx', '205AD222x', '205DM221', '205LN321', '205OS311', '205RM311x', '205SH321', '205VB322', '205WT321', '205AP331', '205SA321', '205SC321', '205SE311', '205SH322', '205WS311', 'S20HR223', '251AI411', '251DI321', '251MI221', '251SM422', '252LS421', '252PM421', '710GE328', 'S00PO101', '252IP431', '252PJ431', '115LS101', '145PY101', '205BC121', '205CP111', '205CS121', '205DB111'
# ...

# %%
subject = []
for item in subject_name:
    subject.append(item)
print(len(subject), subject)
# Out:
# 185 ['ໂຄງສ້າງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ', 'Data Science', 'ການຂຽນໂປຣແກຣມສໍາລັບມືຖື', 'ລະບົບຂ່າວສານເພື່ອການບໍລິຫານ', 'ການພັດທະນາລະບົບດ້ວຍຮູບແບບວັັດຖຸ', 'ລະບົບປະຕິບັດການ', 'ສະຖິຕິວິໄຈ', 'ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ', 'ລະບົບຖານຂໍ້ມູນ', 'Desktop Application Development', 'ການຂຸດຄົົ້ນຂໍ້ມູນ (Data Mining)', 'Mathematics for Computing', 'ການວິເຄາະ ແລະ ອອກແບບລະບົບ', 'ການສ້າງລາຍງານດ້ວຍ Crystal Report', 'ການຄຸູ້ມຄອງຖານຂໍ້ມູນ', 'ວິທີການຄົ້ນຄວ້າ', 'ສໍາມະນາ', 'ວິສະວະກໍາຊອບແວ', 'Web Programming', 'Web Server and Technology', 'ປັນຍາປະດິດ', 'ຄວາມປອດໄພ ແລະ ຈັນຍາບັນການນາໃຊ້ຄອມພິວເຕີ', 'ໂຄງການຈົບຊັ້ນ', 'ການຄ້າດ້ວຍເອເລັກໂທນິກ', 'ລາວສຶກສາ1', 'ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ', 'ຄອມພີວເຕີພື້ນຖານ', 'ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມດ້ວຍ\u200bພາສາ C', 'ລະບົບ\u200bຄອມ\u200bພິວ\u200bເຕີ', 'ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200bຖານ\u200bຂໍ້\u200bມູນ(MS Access)', 'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ 1', 'ລາວ\u200bສຶກສາ2', 'ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ', 'ລະບົບຖານຂໍ້ມູນແບບໂຄງສ້າງ', 'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ2', 'ສະຖິ
# ...

# %%
split_values = ['ໂຄງສ້າງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ','Data Science','ການຂຽນໂປຣແກຣມສໍາລັບມືຖື','ລະບົບຂ່າວສານເພື່ອການບໍລິຫານ',
                'ການພັດທະນາລະບົບດ້ວຍຮູບແບບວັັດຖຸ','ລະບົບປະຕິບັດການ','ສະຖິຕິວິໄຈ','ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ','ລະບົບຖານຂໍ້ມູນ',
                'Desktop Application Development','ການຂຸດຄົົ້ນຂໍ້ມູນ (Data Mining)','Mathematics for Computing',
                'ການວິເຄາະ ແລະ ອອກແບບລະບົບ','ການສ້າງລາຍງານດ້ວຍ Crystal Report','ການຄຸູ້ມຄອງຖານຂໍ້ມູນ','ວິທີການຄົ້ນຄວ້າ',
                'ສໍາມະນາ','ວິສະວະກໍາຊອບແວ','Web Programming','Web Server and Technology','ປັນຍາປະດິດ',
                'ຄວາມປອດໄພ ແລະ ຈັນຍາບັນການນາໃຊ້ຄອມພິວເຕີ','ໂຄງການຈົບຊັ້ນ','ການຄ້າດ້ວຍເອເລັກໂທນິກ','ລາວສຶກສາ1',
                'ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ','ຄອມພີວເຕີພື້ນຖານ','ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມດ້ວຍ\u200bພາສາ C',
                'ລະບົບ\u200bຄອມ\u200bພິວ\u200bເຕີ','ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200bຖານ\u200bຂໍ້\u200bມູນ(MS Access)',
                'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ 1','ລາວ\u200bສຶກສາ2','ການສື່ສານຂໍ້ມູນ ແລະ ເຄືອຂ່າຍ','ລະບົບຖານຂໍ້ມູນແບບໂຄງສ້າງ',
                'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ2','ສະຖິຕິ\u200bພື້ນຖານ','\u200bພາສາໂປຣ\u200bແກຣມ1(Java1)','ຄະນິດສາດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1',
                '\u200bໂຄງ\u200bສ້າງ\u200bຂໍ້\u200bມູນ \u200bແລະ ຂັ້ນ\u200bຕອນ\u200bວິທີ','ພື້ນຖານການບໍລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Linux',
                'ການຂຽນໂປຣແກຣມດ້ວຍພາສາ C# 1','ພາສາ\u200bອັງກິດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1',
                'ການອ\u200bອກ\u200bແບບ UX-UI','ພາສາໂປຣ\u200bແກຣມ2(Java2)','ພື້ນຖານການບໍລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Window',
                'ພາສາ\u200bອັງກິດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ2','ການປະມວນຜົນຮູບພາບ','ການຂຽນໂປຣແກຣມດ້ວຍພາສາ C# 2',
                'MOS','ສຶກສາປ້ອງກັນຕົວ','ການວິເຄາະ ແລະ ອອກແບບລັກສະນະວັດຖຸ','\u200bໂຄງ\u200bສ້າງ\u200bຂໍ້\u200bມູນ \u200bແລະ ຂັ້ນ\u200bຕອນ\u200bວິທີ2',
                'ດາຕາ ມາຍນິ່ງ (Data Mining)','ພື້ນຖານການບໍລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Linux','ລະບົບ\u200bປະຕິບັດ\u200bການ','ວິທີ\u200bການ\u200bຄົ້ນ\u200bຄ້ວາ',
                'ການຂຽນໂປຣແກຣມດ້ວຍພາສາ C# 1','ການຂຽນໂປຣແກຣມດ້ວຍ VB.NET 2','ເວບເຊີເວີ ແລະ ເວບເທັກໂນໂລຢີ','CompTIA A+',
                'ການວິເຄາະ ແລະ ອອກແບບລະບົບ(ສໍາລັບໂປແກມ)','ສຳມະນາ 1','ວິສະວະກຳຊັອບແວ (Process and Tools)',
                'ການຂຽນໂປຣແກຣມດ້ວຍພາສາ C# 2','ການບໍລິຫານເຄື່ອງແມ່ຂ່າຍ ດ້ວຍ Windows','ມະນຸດ\u200bສໍາພັນ','ປັນຍາປະດິດ','ສະຖາປັດຕະຍະກໍາຊອບແວ',
                'ລະບົບຂ່າວສານເພື່ອການບໍລິຫານ','ສໍາມະນາ2','ບໍ່ລິຫານເຄື່ອງແມ່ຂ່າຍດ້ວຍ Linux','ການບໍລິຫານໂຄງການ','ບໍລິຫານການສຶກສາ',
                'ການເມືອງ','ເຝິກງານ','ໂຄງການຈົບຊັ້ນ/ສອບເສັງ','ລາວສຶກສາ1','ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ','ການນໍາໃຊ້ຊອບແວພື້້ນຖານ',
                'ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມດ້ວຍ\u200bພາສາ C','ລະບົບຄອມພິວເຕີ','ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200bຖານ\u200bຂໍ້\u200bມູນ(MS Access)',
                'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ 1','ຄະນິດສາດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1','ລາວ\u200bສຶກສາ2',
                '\u200bແຄລຄູ\u200bລັດສ໌ 1','ລະບົບຖານຂໍ້ມູນ(Database Systems)','ພາສາອັງກິດສໍາລັບວິທະຍາສາດ2','ສະຖິຕິ\u200bພື້ນຖານ',
                'ລະບົບປະຕິບັດການ','ການຂຽນໂປຣແກຣມພາສາ Python ສໍາລັບ Data Science','ໂຄງ\u200bສ້າງ\u200bຂໍ້\u200bມູນ ແລະ ຂັ້ນ\u200bຕອນ\u200bວິທີ',
                'ແຄນ\u200bຄູ\u200bລັດ\u200bສ໌ 2','ດາຕາຊາຍ(Data Science)','ພາສາ\u200bອັງກິດ\u200bສຳລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ 1',
                'ຄະນິດສາດ\u200bສຳລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ 2','ລະບົບ\u200bຂ່າວສານ\u200bເພື່ອ\u200bການ\u200bບໍລິຫານ(MIS)',
                'ການຂຽນໂປຣແກຣມພາສາ R ສໍາລັບ Data Science','ສຶກສາປ້ອງກັນຕົວ(ບໍ່ໄດ້ຈ່າຍຄ່າໜ່ວຍກິດ)','ມະນຸດ\u200bສຳພັນ',
                'ໂຄງ\u200bສ້າງ\u200bຂໍ້\u200bມູນ ແລະ ຂັ້ນ\u200bຕອນ\u200bວິທີ 2','ດາຕາ ມາຍນິ່ງ (Data Mining)',
                'Database Programming','ການ\u200bວິເຄາະ ແລະ ອອກ\u200bແບບ\u200bລະບົບ(ແບບວັດຖຸ)','ສະຖິຕິ\u200bເພື່ອ\u200bງານ\u200bວິ\u200bໄຈ',
                'ປັນຍາປະດິດ (Artificial Intelligence)','ການ\u200bສື່ສານ\u200bຂໍ້\u200bມູນ \u200bແລະ \u200bເຄືອ\u200bຂ່າຍ',
                'Computer Vision: ປະມວນຜົນຮູບພາບ (Digital Image Pro...','ພາສາອັງກິດສຳລັບຄອມພິວເຕີ 2','ໄຟຟ້າສໍາລັບຄອມພິວເຕີ (Electricity 1)',
                'ການສືບຄົ້ນຂໍ້ມູນຂ່າວສານ (Information Retrieval)','ວິທີການຄົຶ້ນຄວ້າ (ວິທະຍາສາດຄອມພິວເຕີ)','ການບໍາລຸງຮັກສາ ແລະ ແກ້ໄຂບັນຫາຄອມພິວເຕີ (CompTIA A+...',
                'Introduction to Blockchain Technology','ຄອມພິວເຕີກຣາບຟິກ','ມາຊີນເລີນນິ່ງ\xa0(Machine Learning)',
                'ວິສະວະກຳຊັອບແວ','Computer Security and Forensics','ສຳມະນາ 1','ການບໍລິຫານເຄື່ອງແມ່ຂ່າຍ',
                'ວິຊາການ\u200bເມືອງ','ບິກດາຕາ (Introduction to Big Data)','Intoduction to Cloud Computing','ພາສາອັງກິດສໍາລັບຄອມພິວເຕີ3',
                'ການຄ້າດ້ວຍເອເລັກໂຕຣນິກ(E-Commerce)','Hybrid Mobile App','Introduction to the Internet of Things (IOT)',
                'ສໍາມະນາ2','ໂຄງການຈົບຊັ້ນ/ສອບເສັງ','ລົງເຝິກງານ/ບົດໂຄງການນ້ອຍ','ລາວສຶກສາ1','ຈິດຕະວິທະຍາ\u200bທົ່ວ\u200bໄປ',
                'ການນໍາໃຊ້ຊອບແວພື້້ນຖານ','ລະບົບຄອມພິວເຕີ','ຄວາມ\u200bຮູ້\u200bພື້ນຖານ\u200bກ່ຽວ\u200bກັບ\u200b\u200bຖານ\u200bຂໍ້\u200bມູນ (Ms Access)',
                'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ 1','\u200bພາສາໂປຣ\u200bແກຣມ1(Java1)','ຄະນິດສາດ\u200bສໍາລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ1',
                'ລາວ\u200bສຶກສາ2','ການ\u200bສື່ສານ\u200bຂໍ້\u200bມູນ \u200bແລະ \u200bເຄືອ\u200bຂ່າຍ','ລະບົບຖານ\u200bຂໍ້\u200bມູນ (Database Systems)',
                'ພາສາອັງກິດສໍາລັບວິທະຍາສາດ2','ຄະນິດສາດ\u200bສຳລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ 2','ການອອກແບບເວັບໄຊ',
                'ພື້ນຖານເວບໂປຣແກຣມມິງ','ຄອມພິວເຕີກຣາຟິກ','ໂຄງສ້າງຂອງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ ສໍາລັບການພັດທະນາເ...',
                'ພາສາ\u200bອັງກິດ\u200bສຳລັບ\u200bຄອມ\u200bພິວ\u200bເຕີ 1','\u200bເຕັກ\u200bໂນ\u200bໂລ\u200bຊີ\u200bຂ່າ\u200bວສານ',
                '\u200bການພັດທະນາເວບໄຊດ້ວຍພາສາ JSP1','ການ\u200bຂຽນ\u200bໂປຣ\u200bແກຣມ\u200bເທິງ\u200bມື\u200bຖື 1',
                'ລະບົບປະ\u200bຕິ\u200bບັດ\u200bການ','ການພັດທະນາເວບໄຊດ້ວຍພາສາ PHP1','ສຶກສາປ້ອງກັນຕົວ(ບໍ່ໄດ້ຈ່າຍຄ່າໜ່ວຍກິດ)',
                'ການບໍາລຸງຮັກສາ ແລະ ແກ້ໄຂບັນຫາຄອມພິວເຕີ (CompTAI A+...','ໂຄງສ້າງຂອງຂໍ້ມູນ ແລະ ຂັ້ນຕອນວິທີ ສໍາລັບການພັດທະນາເ...',
                'Hybrid Mobile App','ລະບົບ\u200bຂ່າວສານ\u200bເພື່ອ\u200bການ\u200bບໍລິຫານ(MIS)','ສະຖິຕິ\u200bເພື່ອ\u200bງານ\u200bວິ\u200bໄຈ',
                'ການພັດທະນາເວບໄຊດ້ວຍພາສາ JSP2+framework','ການສ້າງເວບດ້ວຍ ASP.net 1','ພາສາອັງກິດສຳລັບຄອມພິວເຕີ 2',
                'ການຄ້າດ້ວຍເອເລັກໂຕຣນິກ(E-Commerce)','ການພັດທະນາເວບໄຊດ້ວຍພາສາ PHP2 + Framework','ວິທີການຄົ້ນຄ້ວາ',
                'ການບໍລິຫານເຄື່ອງແມ່ຂ່າຍ','ເວບເຊີເວີ ແລະ ເວບເທັກໂນໂລຢີ','ມະນຸດ\u200bສຳພັນ','ການພັດທະນາເວບໄຊດ້ວຍພາສາ ASP.net2+framework',
                'Introduction to the Internet of Things (IOT)','ການຂຽນໂປຣແກຣມເທິງມືຖື 2','ມາຊີນເລີນນິ່ງ\xa0(Machine Learning)',
                'ສຳມະນາ 1','ວິສະວະກຳຊັອບແວ (Process and Tools)','ຄວາມປອດໄພຂອງເວບໄຊ','ວິຊາການ\u200bເມືອງ','ປັນຍາປະດິດ',
                'MOS','Data Mining','ພາສາອັງກິດສໍາລັບຄອມພິວເຕີ3','ການວິເຄາະ ແລະ ການອອກແບບລະບົບ','ສໍາມະນາ2','ຍຸດທະສາດໃນການວາງແຜນລະບົບຂ່າວສານ',
                'ໂຄງການຈົບຊັ້ນ/ສອບເສັງ','ລົງເຝິກງານ/ບົດໂຄງການນ້ອຍ']

items_to_insert = [['ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ'],['Data','Science'],['ການຂຽນ','ໂປຣແກຣມ','ສຳລັບ','ມືຖື'],
                   ['ລະບົບ','ຂ່າວສານ','ເພື່ອ','ການບໍລິຫານ'],['ການພັດທະນາ','ລະບົບ','ດ້ວຍ','ຮູບແບບ','ວັດຖຸ'],
                   ['ລະບົບ','ປະຕິບັດການ'],['ສະຖິຕິ','ວິໄຈ'],['ການສື່ສານ','ຂໍ້ມູນ','ແລະ','ເຄືອຂ່າຍ'],['ລະບົບ','ຖານຂໍ້ມູນ'],
                   ['Desktop','Application','Development'],['ການຂຸດຄົົ້ນ','ຂໍ້ມູນ','Data','Mining'],
                   ['Mathematics','for','Computing'],['ການວິເຄາະ','ແລະ','ອອກແບບ','ລະບົບ'],['ການສ້າງ','ລາຍງານ',
                    'ດ້ວຍ','Crystal','Report'],['ການຄຸູ້ມຄອງ','ຖານຂໍ້ມູນ'],['ວິທີ','ການຄົ້ນຄວ້າ'],['ສຳມະນາ'],
                   ['ວິສະວະກຳ','ຊອບແວ'],['Web','Programming'],['Web','Server','and','Technology'],['ປັນຍາ','ປະດິດ'],
                   ['ຄວາມປອດໄພ','ແລະ','ຈັນຍາບັນ','ການນຳໃຊ້','ຄອມພິວເຕີ'],['ໂຄງການ','ຈົບຊັ້ນ'],['ການຄ້າ','ດ້ວຍ',
                    'ເອເລັກໂທນິກ'],['ລາວ','ສຶກສາ'],['ຈິດຕະວິທະຍາ','ທົ່ວໄປ'],['ຄອມພິວເຕີ','ພື້ນຖານ'],['ການຂຽນ','ໂປຣແກຣມ',
                    'ດ້ວຍ','ພາສາ','C'],['ລະບົບ','ຄອມພິວເຕີ'],['ຄວາມຮູ້','ພື້ນຖານ','ກ່ຽວກັບ','ຖານຂໍ້ມູນ','MS','Access'],
                   ['ພາສາອັງກິດ','ສຳລັບ','ວິທະຍາສາດ'],['ລາວ','ສຶກສາ'],['ການສື່ສານ','ຂໍ້ມູນ','ແລະ','ເຄືອຂ່າຍ'],
                   ['ລະບົບ','ຖານຂໍ້ມູນ','ແບບ','ໂຄງສ້າງ'],['ພາສາອັງກິດ','ສຳລັບ','ວິທະຍາສາດ'],['ສະຖິຕິ','ພື້ນຖານ'],
                   ['ພາສາ','ໂປຣແກຣມ','Java'],['ຄະນິດສາດ','ສຳລັບ','ຄອມພິວເຕີ'],['ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ'],
                   ['ພື້ນຖານ','ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ','ດ້ວຍ','Linux'],['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','ພາສາ','C#'],
                   ['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ການອອກແບບ','UX-UI'],['ພາສາ','ໂປຣແກຣມ','Java'],
                   ['ພື້ນຖານ','ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ','ດ້ວຍ','Window'],['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],
                   ['ການປະມວນຜົນ','ຮູບພາບ'],['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','ພາສາ','C#'],['MOS'],['ສຶກສາ','ປ້ອງກັນ','ຕົວ'],
                   ['ການວິເຄາະ','ແລະ','ອອກແບບ','ລັກສະນະ','ວັດຖຸ'],['ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ'],
                   ['ດາຕາມາຍນິ່ງ','Data','Mining'],['ພື້ນຖານ','ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ','ດ້ວຍ','Linux'],
                   ['ລະບົບ','ປະຕິບັດການ'],['ວິທີ','ການຄົ້ນຄວ້າ'],['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','ພາສາ','C#'],
                   ['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','VB.NET'],['ເວັບເຊີເວີ','ແລະ','ເວັບເທັກໂນໂລຢີ'],['CompTIA','A+'],
                   ['ການວິເຄາະ','ແລະ','ອອກແບບ','ລະບົບ','ສຳລັບ','ໂປຣແກຣມ'],['ສຳມະນາ'],['ວິສະວະກຳ','ຊອບແວ','Process',
                    'and','Tools'],['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','ພາສາ','C#'],['ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ','ດ້ວຍ',
                    'Windows'],['ມະນຸດ','ສຳພັນ'],['ປັນຍາ','ປະດິດ'],['ສະຖາປັດຕະຍະກໍາ','ຊອບແວ'],['ລະບົບ','ຂ່າວສານ',
                    'ເພື່ອ','ການບໍລິຫານ'],['ສຳມະນາ'],['ບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ','ດ້ວຍ','Linux'],['ການບໍລິຫານ','ໂຄງການ'],
                   ['ບໍລິຫານ','ການສຶກສາ'],['ການເມືອງ'],['ເຝິກງານ'],['ໂຄງການ','ຈົບຊັ້ນ','ສອບເສັງ'],['ລາວ','ສຶກສາ'],
                   ['ຈິດຕະວິທະຍາ','ທົ່ວໄປ'],['ການນຳໃຊ້','ຊອບແວ','ພື້ນຖານ'],['ການຂຽນ','ໂປຣແກຣມ','ດ້ວຍ','ພາສາ','C'],
                   ['ລະບົບ','ຄອມພິວເຕີ'],['ຄວາມຮູ້','ພື້ນຖານ','ກ່ຽວກັບ','ຖານຂໍ້ມູນ','MS','Access)'],['ພາສາອັງກິດ','ສຳລັບ',
                    'ວິທະຍາສາດ'],['ຄະນິດສາດ','ສຳລັບ','ຄອມພິວເຕີ'],['ລາວ','ສຶກສາ'],['ແຄລຄູລັດສ໌'],['ລະບົບ','ຖານຂໍ້ມູນ',
                    'Database','Systems'],['ພາສາອັງກິດ','ສຳລັບ','ວິທະຍາສາດ'],['ສະຖິຕິ','ພື້ນຖານ'],['ລະບົບ','ປະຕິບັດການ'],
                   ['ການຂຽນ','ໂປຣແກຣມ','ພາສາ','Python','ສຳລັບ','Data','Science'],['ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ',
                    'ວິທີ'],['ແຄລຄູລັດສ໌'],['ດາຕາຊາຍ','Data','Science'],['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ຄະນິດສາດ',
                    'ສຳລັບ','ຄອມພິວເຕີ'],['ລະບົບ','ຂ່າວສານ','ເພື່ອ','ການບໍລິຫານ','MIS'],['ການຂຽນ','ໂປຣແກຣມ','ພາສາ','R',
                    'ສຳລັບ','Data','Science'],['ສຶກສາ','ປ້ອງກັນ','ຕົວ','ບໍ່ໄດ້','ຈ່າຍ','ຄ່າໜ່ວຍກິດ'],['ມະນຸດ','ສຳພັນ'],
                    ['ໂຄງສ້າງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ'],['ດາຕາມາຍນິ່ງ','Data','Mining'],['Database','Programming'],
                    ['ການວິເຄາະ','ແລະ','ອອກແບບ','ລະບົບ','ແບບ','ວັດຖຸ'],['ສະຖິຕິ','ເພື່ອ','ງານວິໄຈ'],['ປັນຍາ','ປະດິດ',
                    'Artificial','Intelligence'],['ການສື່ສານ','ຂໍ້ມູນ','ແລະ','ເຄືອຂ່າຍ'],['Computer','Vision',
                    'ປະມວນຜົນ','ຮູບພາບ','Digital','Image','Processing'],['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ໄຟຟ້າ',
                    'ສຳລັບ','ຄອມພິວເຕີ','Electricity'],['ການສືບຄົ້ນ','ຂໍ້ມູນຂ່າວສານ','Information','Retrieval'],
                    ['ວິທີ','ການຄົ້ນຄວ້າ','ວິທະຍາສາດ','ຄອມພິວເຕີ'],['ການບໍາລຸງ','ຮັກສາ','ແລະ','ແກ້ໄຂ','ບັນຫາ','ຄອມພິວເຕີ',
                    'CompTIA','A+'],['Introduction','to','Blockchain','Technology'],['ຄອມພິວເຕີ','ກຣາຟິກ'],
                    ['ມາຊີນເລີນນິ່ງ','Machine','Learning'],['ວິສະວະກຳ','ຊອບແວ'],['Computer','Security','and','Forensics'],
                    ['ສຳມະນາ'],['ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ'],['ວິຊາ','ການເມືອງ'],['ບິກດາຕາ','Introduction','to',
                     'Big','Data'],['Intoduction','to','Cloud','Computing'],['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],
                    ['ການຄ້າ','ດ້ວຍ','ເອເລັກໂຕຣນິກ','E-Commerce'],['Hybrid','Mobile','App'],['Introduction','to',
                    'the','Internet','of','Things','IOT'],['ສຳມະນາ'],['ໂຄງການ','ຈົບຊັ້ນ','ສອບເສັງ'],['ລົງ','ເຝິກງານ',
                    'ບົດໂຄງການ','ນ້ອຍ'],['ລາວ','ສຶກສາ'],['ຈິດຕະວິທະຍາ','ທົ່ວໄປ'],['ການນຳໃຊ້','ຊອບແວ','ພື້້ນຖານ'],
                    ['ລະບົບ','ຄອມພິວເຕີ'],['ຄວາມຮູ້','ພື້ນຖານ','ກ່ຽວກັບ','ຖານຂໍ້ມູນ','Ms','Access'],['ພາສາອັງກິດ','ສຳລັບ',
                    'ວິທະຍາສາດ'],['ພາສາ','ໂປຣແກຣມ','Java'],['ຄະນິດສາດ','ສຳລັບ','ຄອມພິວເຕີ'],['ລາວ','ສຶກສາ'],
                    ['ການສື່ສານ','ຂໍ້ມູນ','ແລະ','ເຄືອຂ່າຍ'],['ລະບົບ','ຖານຂໍ້ມູນ','Database','Systems'],['ພາສາອັງກິດ','ສຳລັບ',
                    'ວິທະຍາສາດ'],['ຄະນິດສາດ','ສຳລັບ','ຄອມພິວເຕີ'],['ການອອກແບບ','ເວັບໄຊ'],['ພື້ນຖານ','ເວັບໂປຣແກຣມມິງ'],
                    ['ຄອມພິວເຕີ','ກຣາຟິກ'],['ໂຄງສ້າງ','ຂອງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ','ສຳລັບ','ການພັດທະນາ','ເວັບໄຊ'],
                    ['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ເຕັກໂນໂລຊີ','ຂ່າວສານ'],['ການພັດທະນາ','ເວັບໄຊ','ດ້ວຍ','ພາສາ','JSP'],
                    ['ການຂຽນ','ໂປຣແກຣມ','ເທິງ','ມືຖື'],['ລະບົບ','ປະຕິບັດການ'],['ການພັດທະນາ','ເວັບໄຊ','ດ້ວຍ','ພາສາ','PHP'],
                    ['ສຶກສາ','ປ້ອງກັນ','ຕົວ','ບໍ່ໄດ້','ຈ່າຍ','ຄ່າໜ່ວຍກິດ'],['ການບໍາລຸງ','ຮັກສາ','ແລະ','ແກ້ໄຂ','ບັນຫາ','ຄອມພິວເຕີ',
                    'CompTIA','A+'],['ໂຄງສ້າງ','ຂອງ','ຂໍ້ມູນ','ແລະ','ຂັ້ນຕອນ','ວິທີ','ສຳລັບ','ການພັດທະນາ','ເວັບໄຊ'],
                    ['Hybrid','Mobile','App'],['ລະບົບ','ຂ່າວສານ','ເພື່ອ','ການບໍລິຫານ','MIS'],['ສະຖິຕິ','ເພື່ອ','ງານວິໄຈ'],
                    ['ການພັດທະນາ','ເວັບໄຊ','ດ້ວຍ','ພາສາ','JSP','framework'],['ການສ້າງ','ເວັບ','ດ້ວຍ','ASP.net'],
                    ['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ການຄ້າ','ດ້ວຍ','ເອເລັກໂຕຣນິກ','E-Commerce'],['ການພັດທະນາ',
                    'ເວັບໄຊ','ດ້ວຍ','ພາສາ','PHP','Framework'],['ວິທີ','ການຄົ້ນຄວ້າ'],['ການບໍລິຫານ','ເຄື່ອງແມ່ຂ່າຍ'],
                    ['ເວັບເຊີເວີ','ແລະ','ເວັບເທັກໂນໂລຢີ'],['ມະນຸດ','ສຳພັນ'],['ການພັດທະນາ','ເວັບໄຊ','ດ້ວຍ','ພາສາ','ASP.net',
                    'framework'],['Introduction','to','the','Internet','of','Things','IOT'],['ການຂຽນ','ໂປຣແກຣມ',
                    'ເທິງ','ມືຖື'],['ມາຊີນເລີນນິ່ງ','Machine','Learning'],['ສຳມະນາ'],['ວິສະວະກຳ','ຊອບແວ','Process','and',
                    'Tools'],['ຄວາມປອດໄພ','ຂອງ','ເວັບໄຊ'],['ວິຊາ','ການເມືອງ'],['ປັນຍາ','ປະດິດ'],['MOS'],['Data','Mining'],
                    ['ພາສາອັງກິດ','ສຳລັບ','ຄອມພິວເຕີ'],['ການວິເຄາະ','ແລະ','ການອອກແບບ','ລະບົບ'],['ສຳມະນາ'],['ຍຸດທະສາດ',
                    'ໃນ','ການວາງແຜນ','ລະບົບ','ຂ່າວສານ'],['ໂຄງການ','ຈົບຊັ້ນ','ສອບເສັງ'],['ລົງ','ເຝິກງານ','ບົດໂຄງການ','ນ້ອຍ']]

for split_value, items in zip(split_values, items_to_insert):
    index = 0
    while index < len(subject):
        if subject[index] == split_value:
            # Insert the items after the split value
            for item in items:
                subject.insert(index + 1, item)
            # Move index past the newly inserted items
            index += len(items)
            subject.remove(split_value)
        else:
            index += 1

print(len(subject), subject)
# Out:
# 631 ['ວິທີ', 'ຂັ້ນຕອນ', 'ແລະ', 'ຂໍ້ມູນ', 'ໂຄງສ້າງ', 'Science', 'Data', 'ມືຖື', 'ສຳລັບ', 'ໂປຣແກຣມ', 'ການຂຽນ', 'ການບໍລິຫານ', 'ເພື່ອ', 'ຂ່າວສານ', 'ລະບົບ', 'ວັດຖຸ', 'ຮູບແບບ', 'ດ້ວຍ', 'ລະບົບ', 'ການພັດທະນາ', 'ປະຕິບັດການ', 'ລະບົບ', 'ວິໄຈ', 'ສະຖິຕິ', 'ເຄືອຂ່າຍ', 'ແລະ', 'ຂໍ້ມູນ', 'ການສື່ສານ', 'ຖານຂໍ້ມູນ', 'ລະບົບ', 'Development', 'Application', 'Desktop', 'Mining', 'Data', 'ຂໍ້ມູນ', 'ການຂຸດຄົົ້ນ', 'Computing', 'for', 'Mathematics', 'ລະບົບ', 'ອອກແບບ', 'ແລະ', 'ການວິເຄາະ', 'Report', 'Crystal', 'ດ້ວຍ', 'ລາຍງານ', 'ການສ້າງ', 'ຖານຂໍ້ມູນ', 'ການຄຸູ້ມຄອງ', 'ການຄົ້ນຄວ້າ', 'ວິທີ', 'ສຳມະນາ', 'ຊອບແວ', 'ວິສະວະກຳ', 'Programming', 'Web', 'Technology', 'and', 'Server', 'Web', 'ປະດິດ', 'ປັນຍາ', 'ຄອມພິວເຕີ', 'ການນຳໃຊ້', 'ຈັນຍາບັນ', 'ແລະ', 'ຄວາມປອດໄພ', 'ຈົບຊັ້ນ', 'ໂຄງການ', 'ເອເລັກໂທນິກ', 'ດ້ວຍ', 'ການຄ້າ', 'ສຶກສາ', 'ລາວ', 'ທົ່ວໄປ', 'ຈິດຕະວິທະຍາ', 'ພື້ນຖານ', 'ຄອມພິວເຕີ', 'C', 'ພາສາ', 'ດ້ວຍ', 'ໂປຣແກຣມ', 'ການຂຽນ', 'ຄອມພິວເຕີ', 'ລະບົບ', 'Access', 'MS', 'ຖານຂໍ້ມູນ', 'ກ່ຽວກັບ', 'ພື້ນຖານ', 'ຄວາມຮູ້', 'ວິທະຍາສາດ', 'ສຳລັບ',
# ...

# %%
words.extend(subject)
print(len(words),words)
# Out:
# 816 ['204AD121', '204DS121', '204MB111', '204MI101', '204OO111', '204OS111', '204RE301', '204CN111', '204DB111', '204DD121', '204DM121', '204MC101', '204SA121', '204CR221', '204DA221', '204RC221', '204SC211', '204SE221', '204WP221', '204WS221', '204AI211', '204CS211', '204FP221', '204LN231', '115LS101', '145PY101', '205CF111', '205CP111', '205CS111x', '205DB111', '205ES101', '135LS102', '205CN121', '205DB112x', '205ES102', '205FS111', '205JA121', '205MC111', '205AD221xx', '205LN221', '205SH221', '205EC203x', '205UX211', '205JA222', '205WS211', '205EC102', '205IM221', '205SH322x', '205MO211', '205ND201', '205OD221xxx', '205AD222x', '205DM221', '205LN321', '205OS311', '205RM311x', '205SH321', '205VB322', '205WT321', '205AP331', '205SA321', '205SC321', '205SE311', '205SH322', '205WS311', 'S20HR223', '251AI411', '251DI321', '251MI221', '251SM422', '252LS421', '252PM421', '710GE328', 'S00PO101', '252IP431', '252PJ431', '115LS101', '145PY101', '205BC121', '205CP111', '205CS121', '205DB111'
# ...

# %%
from collections import Counter
c = Counter(words)
print(len(c),c)
# Out:
# 323 Counter({'ສຳລັບ': 26, 'ຄອມພິວເຕີ': 24, 'ດ້ວຍ': 23, 'ແລະ': 21, 'ລະບົບ': 21, 'ໂປຣແກຣມ': 16, 'ພາສາ': 16, 'ພາສາອັງກິດ': 14, 'ຂໍ້ມູນ': 12, 'ການຂຽນ': 12, 'ພື້ນຖານ': 12, 'ວິທີ': 11, 'ການບໍລິຫານ': 11, 'Data': 9, 'ສຶກສາ': 9, 'ເວັບໄຊ': 9, 'ໂຄງສ້າງ': 8, 'ການພັດທະນາ': 8, 'ຖານຂໍ້ມູນ': 8, 'ຂັ້ນຕອນ': 7, 'ສຳມະນາ': 7, 'ຊອບແວ': 7, 'ວິທະຍາສາດ': 7, 'ເຄື່ອງແມ່ຂ່າຍ': 7, 'ເພື່ອ': 6, 'ຂ່າວສານ': 6, 'ລາວ': 6, 'ສະຖິຕິ': 5, 'ການວິເຄາະ': 5, 'ໂຄງການ': 5, 'ຄະນິດສາດ': 5, 'to': 5, 'Science': 4, 'ປະຕິບັດການ': 4, 'ເຄືອຂ່າຍ': 4, 'ການສື່ສານ': 4, 'Mining': 4, 'ອອກແບບ': 4, 'ການຄົ້ນຄວ້າ': 4, 'ວິສະວະກຳ': 4, 'and': 4, 'ປະດິດ': 4, 'ປັນຍາ': 4, 'ຈົບຊັ້ນ': 4, 'C#': 4, 'Introduction': 4, '115LS101': 3, '145PY101': 3, '205ES101': 3, '135LS102': 3, '205ES102': 3, '205MC111': 3, 'ມືຖື': 3, 'ວັດຖຸ': 3, 'ການນຳໃຊ້': 3, 'ການຄ້າ': 3, 'ທົ່ວໄປ': 3, 'ຈິດຕະວິທະຍາ': 3, 'Access': 3, 'ກ່ຽວກັບ': 3, 'ຄວາມຮູ້': 3, 'Java': 3, 'Linux': 3, 'ການອອກແບບ': 3, 'ຕົວ': 3, 'ປ້ອງກັນ': 3, 'A+': 3, 'CompTIA': 3, 'ສຳພັນ': 3, 'ມະນຸດ': 3, 'ການເມືອງ': 3, 'ເຝິກງ
# ...

# %%
c = sorted(c)
print(c)
# Out:
# ['015ND201', '115HR223', '115LS101', '115PO401', '135LS102', '145PY101', '204AD121', '204AI211', '204CN111', '204CR221', '204CS211', '204DA221', '204DB111', '204DD121', '204DM121', '204DS121', '204FP221', '204LN231', '204MB111', '204MC101', '204MI101', '204OO111', '204OS111', '204RC221', '204RE301', '204SA121', '204SC211', '204SE221', '204WP221', '204WS221', '205AD221', '205AD221xx', '205AD222', '205AD222x', '205AI321', '205AI411', '205AP221', '205AP321', '205AP331', '205AS321', '205AS322', '205AS411', '205BC121', '205BD421', '205BT321', '205CA111', '205CA112', '205CC421', '205CF111', '205CG221', '205CG321', '205CN121', '205CN321', '205CP111', '205CS111x', '205CS121', '205CV321', '205DA221', '205DA222', '205DB111', '205DB112x', '205DB121', '205DB122', '205DM221', '205DM421', '205DP221', '205DS122', '205DS221', '205EC102', '205EC201', '205EC203x', '205EC301', '205EC401', '205EM321', '205ES101', '205ES102', '205ET211', '205FP411', '205FS111', '205HM221', '205HM421', '205IM221', '205IO4
# ...

# %%
file_name = "corpus.txt"

existing_items = set()

# Read existing items from the file
try:
    with open(file_name, 'r', encoding='utf-8') as file:
        for line in file:
            # Remove newline characters and add to the set
            existing_items.add(line.strip())
except FileNotFoundError:
    # If the file does not exist, continue as there are no existing items
    pass

with open(file_name, 'a', encoding='utf-8') as file:
    for word in c:
        if word not in existing_items:
            file.write(word + '\n')
            existing_items.add(word)  

print("save successfully")
# Out:
# save successfully
