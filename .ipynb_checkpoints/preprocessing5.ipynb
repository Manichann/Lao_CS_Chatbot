# %%
from laonlp import word_tokenize
import re

# %%
filename = 'Data/master_cs2.txt'
cleaned_file = 'Cleaned_Data/cleaned_master_cs2.txt'

# %% [markdown]
# # Clean Data

# %%
def remove_special_characters(filename, cleanded_file):
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

    pattern = r'[^a-zA-Zກຂຄງຈສຊຍດຕຖທນບປຜຝພຟມຢລຫຼຣວຫອຮໜໝໆຽະາ ິ ີ ຶ ື ໂ ໍເແ ຸ ູຳໄໃ ັ ົ ່ ້ ໌]'
    clean_text = re.sub(pattern, '', text)

    with open(cleanded_file, 'w', encoding='utf-8') as file:
        file.write(clean_text)

remove_special_characters(filename, cleaned_file)


def delete_space(cleaned_file):
    with open(cleaned_file, 'r',encoding='utf-8') as file:
        content = file.read()

    modifile_content = content.replace(" ", "")        

    with open(cleaned_file, 'w', encoding='utf-8') as file:
        file.write(modifile_content)
        
delete_space(cleaned_file)

# %% [markdown]
# # Word Tokenize

# %%
with open(cleaned_file, encoding='utf-8') as file:
    content = file.read()
    words = word_tokenize(content)
print(len(words), words)
# Out:
# 3803 ['ສາລະບານ', 'ຊື່', 'ຫຼັກສູດ', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ການສ້າງ', 'ຫຼັກສູດ', 'ປັດຊະຍາ', 'ຈຸດປະສົງ', 'ຄາດໝາຍ', 'ຜົນ', 'ການຮຽນ', 'ແລະ', 'ອາຊີບ', 'ທີ່', 'ສາມາດ', 'ປະກອບ', 'ໄດ້', 'ພາຍຫຼັງ', 'ສຳເລັດ', 'ການສຶກສາ', 'ຄາດໝາຍ', 'ຜົນ', 'ການຮຽນຮູ້', 'ອາຊີບ', 'ທີ່', 'ສາມາດ', 'ປະກອບ', 'ໄດ້', 'ພາຍຫຼັງ', 'ສຳເລັດ', 'ການສຶກສາການກຳນົດ', 'ເວລາການເປີດ', 'ສອນ', 'ຄາດຄະເນ', 'ແຜນການຮັບ', 'ນັກສຶກສາ', 'ເງື່ອນໄຂ', 'ຂອງ', 'ຜູ້', 'ເຂົ້າ', 'ສຶກສາວິທີການເລືອກ', 'ຜູ້', 'ເຂົ້າ', 'ສຶກສາການຈັດຕັ້ງ', 'ການຮຽນ', 'ການສອນ', 'ໄລຍະ', 'ເວລາການສຶກສາ', 'ເນື້ອໃນ', 'ໂຄງສ້າງ', 'ຂອງ', 'ຫຼັກສູດ', 'ການກຳນົດ', 'ໜ່ວຍ', 'ກິດ', 'ເຂົ້າໃນ', 'ຫຼັກສູດ', 'ການຈັດ', 'ແບ່ງ', 'ລາຍ', 'ວິຊາ', 'ຮຽນ', 'ໃນ', 'ແຕ່ລະ', 'ໝວດ', 'ວິຊາ', 'ແຜນການຮຽນ', 'ການສອນ', 'ໃນ', 'ແຕ່ລະພາກ', 'ຮຽນ', 'ແລະ', 'ແຕ່ລະ', 'ປີ', 'ເນື້ອໃນ', 'ຫຍໍ້', 'ຂອງ', 'ລາຍ', 'ວິຊາການລົງທະບຽນ', 'ຮຽນ', 'ຂໍ້ກຳນົດການວັດ', 'ການປະເມີນຜົນ', 'ການຮຽນ', 'ແລະ', 'ການ', 'ສຳເລັດ', 'ການສຶກສາ', 'ຂໍ້ກຳນົດການວັດ', 'ຜົນ', 'ການຮຽນ', 'ຂໍ້ກຳນົດການປະເມີນຜົນ', 'ການຮຽນ', 'ຂໍ້ກຳນົດການ', 'ສຳເລ
# ...

# %% [markdown]
# # Re-Clean

# %%
split_values = ['ການສຶກສາການກຳນົດ','ເວລາການເປີດ','ແຜນການຮັບ','ສຶກສາວິທີການເລືອກ','ສຶກສາການຈັດຕັ້ງ','ເວລາການສຶກສາ',
                'ແຜນການຮຽນ','ແຕ່ລະພາກ','ວິຊາການລົງທະບຽນ','ຂໍ້ກຳນົດການວັດ','ຂໍ້ກຳນົດການປະເມີນຜົນ','ຂໍ້ກຳນົດການ',
                'ການສຶກສາຄູສອນ','ສາຂາວິທະຍາສາດ','MasterofSciencePrograminComputerScience','ປທວວຄ',
                'MasterofScienceinComputerScience','MScCS','ວິຊາວິທະຍາສາດ','ວິທະຍາສາດທຳມະຊາດ',
                'sthommalynuoledulasomsackinuoledulalchidtavongnuoledula','ຄວາມຄິດສ້າງສັນ','ເພື່ອນຳໃຊ້','ໃຫ້ມີ',
                'ຄວາມຕ້ອງການຕາມ','ທີ່ມີ','ພັດທະນາວິຊາການໃຫ້','ແລ້ວນັກສຶກສາ','ຫຼັກການກ່ຽວກັບ','DataScience','ຂັ້ນຕອນວິທີ',
                'ຫຼັກການເຂົ້າໃນ','ບັນຫາການອອກແບບ','ArtificiaIIntelligence','ໂທສາຂາວິທະຍາສາດ','ເຕັກໂນໂລຊີດີ',
                'ປະຕິບັດການຮຽນ','ມີການປະເມີນຜົນ','ຄາດຄະເນນັກສຶກສາ','ສະແດງວ່າ','ທີ່ຈະ','ໂທດັ່ງ','ວ່າດ້ວຍ',
                'ວິທີການເລືອກ','ກຳນົດໄວ້','ການກຳນົດການຈັດຕັ້ງ','ແຮວັນ','ບໍ່ສາມາດ','ນັກສຶກສາແລະ','ທີ່ເນັ້ນໜັກ','ມີການຂຽນ',
                'ທີ່ເປັນ','ພື້ນຖານທີ່','ຈຳເປັນແຕ່','ຊອບແວການຈັດ','CompulsoryCourses','ຮັກສາວັດທະນາ',
                'ResearchMethodologyinComputerScienceDA','DataStructuresandAlgorithmsAI','AdvancedArtificialIntelligenceBD',
                'BigDataDS','DataScienceML','MachineLearningCG','ComputerVisionRE','ComputerVisionRE','DataMiningOS',
                'OperatingSystemsBT','BlockchainTechnology','ElectiveCourses','CyberSecuritySS','ວິທີການຄົ້ນຄວ້າ',
                'DecisionSupportSystemFDFullStackDevelopmentCCInternetofThingsIoTCCCloudComputing','ຂັ້ນຕອນວິທີ',
                'ລະບົບປະຕິບັດການ','ເຕັກໂນໂລຊີບ','ແຕ່ລະພາກ','DataStructuresandAlgorithms','ວິຊາບັງຄັບ',
                'DataMining','DataScience','MachineLearning','ResearchMethodologyinComputerScience','ComputerVision',
                'AdvancedArtificialIntelligence','BigData','OperatingSystems','ຖ້າມີ','ທັດສະນະສຶກສາ','ຕົວເລກທີ່ເປັນ',
                'ResearchExperimentandEvaluation','ວິຊານີ້','ວິທີການວິໄຈ','ທີ່ເໝາະສົມ','ແລ້ວນັກສຶກສາຍັງ','ສຳມະນາກ່ຽວກັບ',
                'ການປະຕິບັດການວິໄຈ','ອາຈານທີ່ປຶກສາ','ວິຊານີ້ມີ','ສຶກສາກ່ຽວກັບ','ຂັ້ນຕອນວິທີການຮຽນຮູ້','ຈັດການບັນຫາຍ່ອຍ',
                'GraphalgorithmDynamicprogrammingSearchingandSortingNumbertheoryandothermathematicalGeometricalandnetworkflowalgorithmAI',
                'AIArtificailIntelligence','SoftwareAgent','ວິທີການທີ່','ທີ່ໃຊ້','ພື້ນຖານທີ່ໃຊ້','ທີ່ເຄືອຂ່າຍ','artificialneuralnetwork',
                'machinelearning','ວິທີການແບບ','ການສຶກສາກ່ຽວກັບ','Turingmachine','ວ່າການຄິດ','ການຈັດການສັນຍາລັກ',
                'classificationlinearregressionsupportvectormachineshiddenMarkovmodelsandBayesiannetworks',
                'ນັກສຶກສາມີ','ວິຊານັກສຶກສາ','ຮູບພາບອານ','ສຶກສາການປະມວນ','ວັດຖຸນອກຈາກ','ທາງການປະມວນ','stillimages',
                'imagestreamsRE','ວິຊາການປະເມີນຜົນ','ຈາກການຄົ້ນຄວ້າ','OutputDM','ວິຊາວິຊານີ້','ວິທີການປະມວນ','ແບບອອນລາຍ',
                'ແບບແຜນພາບ','ເພື່ອການຕັດສິນໃຈ','ນັກສຶກສາຍັງ','ວິທີການຂຸດຄົ້ນ','WebminingTextmining','WeakaRapidMinerRPython',
                'ລະບົບປະຕິບັດການລາຍ','ຫຼັກການຈັດການ','VVolumeVelocity','VarietyVolume','ມະຫາສານທີ່',
                'ແມ່ນຄວາມໄວ','ທີ່ມີການເພີ່ມຂຶ້ນ','ຕ້ອງການທີ່ຈະ','ມີການປະມວນ','ທັນຕາມ','ເຮັດໃຫ້',
                'ທີ່ໃຊ້','OSSOpenSourceSoftware','OpenSource','ເຮັດການແກ້ໄຂ','SQLNoSQLDatabase','SemiStructured',
                'UnstructuredDVTDataVisualizationTools','ທີ່ຜ່ານການວິເຄາະ','ມາສະແດງ','ADAnalyticDatabase',
                'ມາກ່ອນ','ວິທີການເຮັດ','ຫາວິທີການສ້າງ','ໄດ້ດີ','ນີ້ມີ','ຄວາມຮູ້ຄວາມເຂົ້າໃຈ','ຂະບວນການຕັດສິນໃຈ',
                'ມີການແນະນຳ','CloudComputing','ທີ່ເຮັດການບໍລິການໃຫ້','ບໍລິການເຖິງ','ມີຄ່າໃຊ້ຈ່າຍ',
                'SoftwareCloudComputing','SoftwareasaServiceSaaSPlatformasaServicePaaS','InfrastructureasaServiceIaaSIS',
                'ຂໍ້ມູນຂ່າວສານ','ທີ່ເກີດຂຶ້ນ','ແຕ່ລະວັນທີ່','ກ່ຽວຂ້ອງກັບ','ໃຫ້ເຫັນ','ສຶກສາແລະ','ຮູບແບບອື່ນ','ນັກສຶກສາມະຫາວິທະຍາໄລ',
                'ແລ້ວນັກສຶກສາ','ນັກສຶກສາແລ້ວຈຶ່ງມີ','ຂໍ້ກຳນົດການວັດ','ຂໍ້ກຳນົດການປະເມີນຜົນ','FairlyGood','VeryGood','VeryPoor',
                'ຂໍ້ກຳນົດການ','ການສຶກສານັກສຶກສາ','ການສຶກສາແລະ','ກຳນົດໄວ້','ຄະນະກຳມະການຢ່າງ','ຄະນະກຳມະການ','ວິຊາການທີ່',
                'ມີຄຸນສົມບັດ','ວິທະຍາສາດທຳມະຊາດ','ວິຊາບັງຄັບ','ກໍລະນີນັກສຶກສາບໍ່','ວິຊານັ້ນ','ກຳນົດໄວ້','ນັກສຶກສາກັບ',
                'ພາຍໃນປະເທດ','ກີບລາຍຮັບ','MotivationLetter','ຈາກການລົງທະບຽນ','ທີ່ເຫຼືອ','ທັດສະນະສຶກສານັກສຶກສາ','ຖ້າມີນອກຈາກ',
                'ໂທສະບັບ','ໄປຕາມ', 'ທີ່ເນັ້ນ','ວັນທີມີນາ','ນັກສຶກສາການຈັດການຮຽນ', 'ບໍລິການສະບັບ','ວັນທີມິຖຸນາ','ການແກ້ບັນຫາ',
                'ຈ່າຍຄ່າ','ບໍ່ມີ', 'ບໍ່ໄດ້','ວ່າມີ']

items_to_insert = [['ການສຶກສາ','ການກຳນົດ'],['ເວລາ','ການເປີດ'],['ແຜນ','ການຮັບ'],['ສຶກສາ','ວິທີ','ການເລືອກ'],
                   ['ສຶກສາ','ການຈັດຕັ້ງ'],['ເວລາ','ການສຶກສາ'],['ແຜນ','ການຮຽນ'],['ແຕ່ລະ','ພາກ'],['ວິຊາ','ການລົງທະບຽນ'],
                   ['ຂໍ້ກຳນົດ','ການວັດ'],['ຂໍ້ກຳນົດ','ການປະເມີນຜົນ'],['ຂໍ້ກຳນົດ','ການ'],['ການສຶກສາ','ຄູສອນ'],
                   ['ສາຂາ','ວິທະຍາສາດ'],['Master','of','Science','Program','in','Computer','Science'],['ປທວ.ວຄ'],
                   ['Master','of','Science','in','Computer','Science'],['M.Sc.CS'],['ວິຊາ','ວິທະຍາສາດ'],
                   ['ວິທະຍາສາດ','ທຳມະຊາດ'],['s.thommaly@nuol.edu.la','somsacki@nuol.edu.la','l.chidtavong@nuol.edu.la'],
                   ['ຄວາມຄິດ','ສ້າງສັນ'],['ເພື່ອ','ນຳໃຊ້'],['ໃຫ້','ມີ'],['ຄວາມຕ້ອງການ','ຕາມ'],['ທີ່','ມີ'],
                   ['ພັດທະນາ','ວິຊາການ','ໃຫ້'],['ແລ້ວ','ນັກສຶກສາ'],['ຫຼັກການ','ກ່ຽວກັບ'],['Data','Science'],['ຂັ້ນຕອນ','ວິທີ'],
                   ['ຫຼັກການ','ເຂົ້າໃນ'],['ບັນຫາ','ການອອກແບບ'],['Artificial','Intelligence'],['ໂທ','ສາຂາ','ວິທະຍາສາດ'],
                   ['ເຕັກໂນໂລຊີ','ດີ'],['ປະຕິບັດ','ການຮຽນ'],['ມີ','ການປະເມີນຜົນ'],['ຄາດຄະເນ','ນັກສຶກສາ'],['ສະແດງ','ວ່າ'],
                   ['ທີ່','ຈະ'],['ໂທ','ດັ່ງ'],['ວ່າ','ດ້ວຍ'],['ວິທີ','ການເລືອກ'],['ກຳນົດ','ໄວ້'],['ການກຳນົດ','ການຈັດຕັ້ງ'],
                   ['ແຮ','ວັນ'],['ບໍ່','ສາມາດ'],['ນັກສຶກສາ','ແລະ'],['ທີ່','ເນັ້ນໜັກ'],['ມີ','ການຂຽນ'],['ທີ່','ເປັນ'],
                   ['ພື້ນຖານ','ທີ່'],['ຈຳເປັນ','ແຕ່'],['ຊອບແວ','ການຈັດ'],['Compulsory','Courses'],['ຮັກສາ','ວັດທະນະທຳ'],
                   ['Research','Methodology','in','Computer','Science'],['Data','Structures','and','Algorithms'],
                   ['Advanced','Artificial','Intelligence'],['Big','Data'],['Data','Science'],['Machine','Learning'],
                   ['Computer','Vision'],['Computer','Vision'],['Data','Mining'],['Operating','Systems'],
                   ['Blockchain','Technology'],['Elective','Courses'],['Cyber','Security'],['ວິທີ','ການຄົ້ນຄວ້າ'],
                   ['Decision','Support','System','Full','Stack','Development','Internet','of','Things','IoT',
                    'Cloud','Computing'],['ຂັ້ນຕອນ','ວິທີ'],['ລະບົບ','ປະຕິບັດການ'],['ເຕັກໂນໂລຊີ'],['ແຕ່ລະ','ພາກ'],
                   ['Data','Structures','and','Algorithms'],['ວິຊາ','ບັງຄັບ'],['Data','Mining'],['Data','Science'],
                   ['Machine','Learning'],['Research','Methodology','in','Computer','Science'],['Computer','Vision'],
                   ['Advanced','Artificial','Intelligence'],['Big','Data'],['Operating','Systems'],['ຖ້າ','ມີ'],
                   ['ທັດສະນະ','ສຶກສາ'],['ຕົວເລກ','ທີ່','ເປັນ'],['Research','Experiment','and','Evaluation'],['ວິຊາ','ນີ້'],
                   ['ວິທີ','ການວິໄຈ'],['ທີ່','ເໝາະສົມ'],['ແລ້ວ','ນັກສຶກສາ','ຍັງ'],['ສຳມະນາ','ກ່ຽວກັບ'],['ການປະຕິບັດ','ການວິໄຈ'],
                   ['ອາຈານ','ທີ່ປຶກສາ'],['ວິຊາ','ນີ້','ມີ'],['ສຶກສາ','ກ່ຽວກັບ'],['ຂັ້ນຕອນ','ວິທີ','ການຮຽນຮູ້'],
                   ['ຈັດການ','ບັນຫາ','ຍ່ອຍ'],['Graph','algorithm','Dynamic','programming','Searching','and','Sorting',
                   'Number','theory','and','other','mathematical','Geometrical','and','network','flow','algorithm'],
                   ['AI','Artificial','Intelligence'],['Software','Agent'],['ວິທີການ','ທີ່'],['ທີ່','ໃຊ້'],['ພື້ນຖານ','ທີ່','ໃຊ້'],
                   ['ທີ່','ເຄືອຂ່າຍ'],['artificial','neural','network'],['machine','learning'],['ວິທີການ','ແບບ'],
                   ['ການສຶກສາ','ກ່ຽວກັບ'],['Turing','machine'],['ວ່າ','ການຄິດ'],['ການຈັດການ','ສັນຍາລັກ'],
                   ['classification','linear','regression','support','vector','machines','hidden','Markov','models',
                   'and','Bayesian','networks'],['ນັກສຶກສາ','ມີ'],['ວິຊາ','ນັກສຶກສາ'],['ຮູບພາບ','ອານ'],['ສຶກສາ','ການປະມວນ'],
                   ['ວັດຖຸ','ນອກຈາກ'],['ທາງ','ການປະມວນ'],['still','images'],['image','streams'],['ວິຊາ','ການປະເມີນຜົນ'],
                   ['ຈາກ','ການຄົ້ນຄວ້າ'],['Output'],['ວິຊາ','ວິຊາ','ນີ້'],['ວິທີ','ການປະມວນ'],['ແບບ','ອອນລາຍ'],
                   ['ແບບ','ແຜນພາບ'],['ເພື່ອ','ການຕັດສິນໃຈ'],['ນັກສຶກສາ','ຍັງ'],['ວິທີ','ການຂຸດຄົ້ນ'],['Web','mining','Text','mining'],
                   ['Weaka','Rapid','Miner','R','Python'],['ລະບົບ','ປະຕິບັດການ','ລາຍ'],['ຫຼັກການ','ຈັດການ'],['V','Volume','Velocity'],
                   ['Variety','Volume'],['ມະຫາສານ','ທີ່'],['ແມ່ນ','ຄວາມໄວ'],['ທີ່','ມີ','ການເພີ່ມຂຶ້ນ'],
                   ['ຕ້ອງການ','ທີ່','ຈະ'],['ມີ','ການປະມວນ'],['ທັນ','ຕາມ'],['ເຮັດ','ໃຫ້'],['ທີ່','ໃຊ້'],['OSS','Open','Source','Software'],
                   ['Open','Source'],['ເຮັດ','ການແກ້ໄຂ'],['SQL','No','SQL','Database'],['Semi','Structured'],['Unstructured',
                   'DVT','Data','Visualization','Tools'],['ທີ່','ຜ່ານ','ການວິເຄາະ'],['ມາ','ສະແດງ'],['AD','Analytic','Database'],
                   ['ມາ','ກ່ອນ'],['ວິທີ','ການເຮັດ'],['ຫາ','ວິທີ','ການສ້າງ'],['ໄດ້','ດີ'],['ນີ້','ມີ'],
                   ['ຄວາມຮູ້','ຄວາມເຂົ້າໃຈ'],['ຂະບວນການ','ຕັດສິນໃຈ'],['ມີ','ການແນະນຳ'],['Cloud','Computing'],['ທີ່','ເຮັດ','ການບໍລິການ','ໃຫ້'],
                   ['ບໍລິການ','ເຖິງ'],['ມີ','ຄ່າໃຊ້ຈ່າຍ'],['Software','Cloud','Computing'],['Software','as','a','Service','SaaS',
                   'Platform','as','a','Service','PaaS'],['Infrastructure','as','a','Service','IaaS'],['ຂໍ້ມູນ','ຂ່າວສານ'],
                   ['ທີ່','ເກີດຂຶ້ນ'],['ແຕ່ລະ','ວັນທີ່'],['ກ່ຽວຂ້ອງ','ກັບ'],['ໃຫ້','ເຫັນ'],['ສຶກສາ','ແລະ'],['ຮູບແບບ','ອື່ນ'],
                   ['ນັກສຶກສາ','ມະຫາວິທະຍາໄລ'],['ແລ້ວ','ນັກສຶກສາ'],['ນັກສຶກສາ','ແລ້ວ','ຈຶ່ງ','ມີ'],['ຂໍ້ກຳນົດ','ການວັດ'],
                   ['ຂໍ້ກຳນົດ','ການປະເມີນຜົນ'],['Fairly','Good'],['Very','Good'],['Very','Poor'],['ຂໍ້ກຳນົດ','ການ'],
                   ['ການສຶກສາ','ນັກສຶກສາ'],['ການສຶກສາ','ແລະ'],['ກຳນົດ','ໄວ້'],['ຄະນະ','ກຳມະການ','ຢ່າງ'],['ຄະນະ','ກຳມະການ'],
                   ['ວິຊາການ','ທີ່'],['ມີ','ຄຸນສົມບັດ'],['ວິທະຍາສາດ','ທຳມະຊາດ'],['ວິຊາ','ບັງຄັບ'],['ກໍລະນີ','ນັກສຶກສາ','ບໍ່'],
                   ['ວິຊາ','ນັ້ນ'],['ກຳນົດ','ໄວ້'],['ນັກສຶກສາ','ກັບ'],['ພາຍໃນ','ປະເທດ'],['ກີບ','ລາຍຮັບ'],['Motivation','Letter'],
                   ['ຈາກ','ການ','ລົງທະບຽນ'],['ທີ່','ເຫຼືອ'],['ທັດສະນະ','ສຶກສາ','ນັກສຶກສາ'],['ຖ້າ','ມີ','ນອກຈາກ'],
                   ['ໂທ','ສະບັບ'],['ໄປ','ຕາມ'],['ທີ່','ເນັ້ນ'],['ວັນທີ','ມີນາ'],['ນັກສຶກສາ','ການຈັດ','ການຮຽນ'],['ບໍລິການ','ສະບັບ'],
                   ['ວັນທີ','ມິຖຸນາ'],['ການແກ້','ບັນຫາ'],['ຈ່າຍ','ຄ່າ'],['ບໍ່','ມີ'],['ບໍ່','ໄດ້'],['ວ່າ','ມີ']]

for split_value, items in zip(split_values, items_to_insert):
    index = 0
    while index < len(words):
        if words[index] == split_value:
            # Insert the items after the split value
            for item in items:
                words.insert(index + 1, item)
            # Move index past the newly inserted items
            index += len(items)
            words.remove(split_value)
        else:
            index += 1

# %%
items_to_remove = ['ໜ່ວຍ','ກິດ','ການຈັດ','ການ','ii','ປະລິນຍາ','ຕີ','ຄວາມເປັນ','ເລີດ','ດໍາ','ດີ','ຈີ','ຕອນ','ນັກ',
                   'ສົກ','ສົກ','ໆ','ອີງ','ໂມ','ດູນ','ທຳ','RM','ວີ','ເຊິ','ນ','ບ','ຼັ','ອ','ກ','ເຊນ','ຈໍ','າ','ນວນ','CY',
                   'TH','AD','DM','DS','ML','BT','CG','BD','OS','RE','xx','XXXABXXX','ລໍ','ດັບ','ການນຳ','DA',
                   'ຊີນ','ເລ','ີນ','ນິ່ງ','ອານ','ລິດ','ທຶມ','ຢັ່ງ','ການປະມວນ','ສີສະ','ເຕ','ລີ','ໂອ','ວິ','ການຈັດ','ຕຽມ',
                   'ຊິນ','ໂກ','ຣ','ນີເຊ','ຊັນ','ແບບອະ','ຊັນເດດ','ລັອກ','ດິບ','ຊ່ອງ','ຫວ່າງ','ຊູດູ','ໂຄດ','SS','ຈຸດ','ມຸ່ງ',
                   'ໜາຍ','ຄວາມ','ເຫຼົ່າ','ບາງ','CC','ອອນ','ໄລ','ແຍງ','ຂ','ຄ','ງ','ຕ','ປະ','ກາ','ສະນິຍະບັດ',
                   'ກອງ','ຕໍ','ແໜ່','ງ','ເບີ','ຈປ','ສົມສັກ','ອິນ','ທະ','ຈ','ປອນ','ລັດສະຫມີ','ຈິດຕະ','ວົງ','ພູທອນ',
                   'ປະສິດ','ຈປທ','ອາ','ມອນ','ຈັນທະ','ພາວົງ','ສຸ','ມະໂນ','ທໍ','ລດ','ແຫນ','່ງ','ວຸດທິການສຶກສາ','ຈົບຈາກ',
                   'ຊ','ມະຫາສານການຂຸດຄົ້ນ','DataMiningDataScienceAIDatabaseTechnologyBigDataInternetofThingsIoT',
                   'ຍ','ວິທີການຄົ້ນຄວ້າ','ComputerVisionImageProcessing','ສປ','VehicularAdhocNetworksArtificialIntelligent',
                   'ຄໍ','ເພັດ','ບຸນ','ນະ','ວິສະວະ','ກໍ','ລະບົບປະຕິບັດການ','DatabaseTechnologyDataScience','ສົມ','ສະຫນຸກ',
                   'ປະທຸມວັນ','ຈຼັນ','WebTechnology','າຊ','AlgorithmInnovation','ມິດ','ທຸມ','ມາລີ',
                   'DataMiningMachineLearning','ບົວ','ສົດ','ໄຊຍະ','ຈຼັກຊ','AlgorithmOperatingSystem','ວິໄລ',
                   'ໄຊເບີການພັດທະນາ','ຟູ','ສະ','ແຕ','ັກ','ຳ','ມະ','ຈນ','ໆ','ໃບ','ລາ','ນຳ','ຕົວ','ຈັດ','ເອກກະສານ',
                   'ສສ','ລັດຖະ','ບັນຍັດ','ຄ່າ','ຄລາວ','ResearchExperimentandEvaluationDM','ຄາດ','ວິສະວະກະ','ເບີ່ງ','ໂທສະບັບ']
items_to_add = ['ໜ່ວຍກິດ','ການຈັດແບ່ງ','ພາກຮຽນ','ການສຳເລັດ','ຮັບເຊີນ','ປະລິນຍາໂທ','ພາກວິຊາ','ປະລິນຍາຕີ','ຄວາມເປັນເລີດ',
                'ເຊື່ອມໂຍງ','ປັນຍາປະດິດ','ດຳລົງຊີວິດ','ຜູ້ຮຽນ','ດັ່ງນີ້','ແກ່ຍາວ','ດິຈິຕອນ','ນັກພັດທະນາ','ສົກສຶກສາ','ສົກຮຽນ',
                'ຕໍ່ໆ','ອີງຕາມ','ຄ່າຮຽນ','ອື່ນໆ','ໂມດູນ','ວີເຊິນ','ບຼັອກເຊນ','ຈຳນວນ','ຄຳອະທິບາຍ','ລຳດັບ','ອະນຸປະລິນຍາ',
                'ການນຳສະເໜີ','ຜົນງານ','ເປັນປະຈໍາ','ນຳສະເໜີ','ຈາກນັ້ນ','ເຫຼົ່ານັ້ນ','ອີກດ້ວຍ','ມາຊີນເລີນນິ່ງ','ຫຼາຍໆ','ຢັ່ງຮູ້',
                'ການປະມວນຜົນ','ສີ','ສະເຕລີໂອວິເຊິນ','ປະມວນຜົນ','ການຈັດຕຽມ','ຊິນໂກຣນີເຊຊັນ','ແບບ','ອະຊິນໂກຣນີເຊຊັນ',
                'ເດດລັອກ','ໜ່ວຍເກັບຂໍ້ມູນ','ໝວດໝູ່','ຂໍ້ມູນດິບ','ໄດ້','ຊ່ອງຫວ່າງ','ຊູດູໂຄດ','ຜູ້ບໍລິຫານ','ຈຸດມຸ່ງໜາຍ','ຄວາມສະດວກ',
                'ເຫຼົ່ານີ້','ບາງສ່ວນ','ໜ່ວຍຈັດເກັບ','ອອນໄລ','ເບິ່ງແຍງ','ການເຕືອນໄພ','ພາບລວມ','ຄ່າຮຽນ','ປະກາສະນີຍະບັດ',
                'ຢ່າງໜ້ອຍ','ບົດນຳສະເໜີ','ກອງປະຊຸມ','ຕຳແໜ່ງ','ເບີໂທ','ວຸດທິ','ການສຶກສາ','ຈາກ','ມະຫາສານ','ການຂຸດຄົ້ນ',
                'ວິສະວະກຳ','ລະບົບ','ປະຕິບັດການ','ໄຊເບີ','ຟູນສະແຕັກ','ຄ່າໜ່ວຍກິດ','ຄ່າລົງທະບຽນ','ນັ້ນໆ','ໃບຄຳຮ້ອງ','ໃບສະເໜີ',
                'ໃບນຳສົ່ງ','ໃບຢັ້ງຢືນ','ໃບອະນຸຍາດ','ລາພັກ','ນຳສົ່ງ','ປະຈໍາຕົວ','ຈັດພິມ','ລັດຖະບັນຍັດ','ຄ່າບໍລິການ','ຄລາວຄອມພິວຕິ້ງ',
                'B+','C+','D+']

words = [item for item in words if item not in items_to_remove]
words.extend(items_to_add)
print(len(words), words)
# Out:
# 3860 ['ສາລະບານ', 'ຊື່', 'ຫຼັກສູດ', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ການສ້າງ', 'ຫຼັກສູດ', 'ປັດຊະຍາ', 'ຈຸດປະສົງ', 'ຄາດໝາຍ', 'ຜົນ', 'ການຮຽນ', 'ແລະ', 'ອາຊີບ', 'ທີ່', 'ສາມາດ', 'ປະກອບ', 'ໄດ້', 'ພາຍຫຼັງ', 'ສຳເລັດ', 'ການສຶກສາ', 'ຄາດໝາຍ', 'ຜົນ', 'ການຮຽນຮູ້', 'ອາຊີບ', 'ທີ່', 'ສາມາດ', 'ປະກອບ', 'ໄດ້', 'ພາຍຫຼັງ', 'ສຳເລັດ', 'ການກຳນົດ', 'ການສຶກສາ', 'ການເປີດ', 'ເວລາ', 'ສອນ', 'ຄາດຄະເນ', 'ການຮັບ', 'ແຜນ', 'ນັກສຶກສາ', 'ເງື່ອນໄຂ', 'ຂອງ', 'ຜູ້', 'ເຂົ້າ', 'ການເລືອກ', 'ວິທີ', 'ສຶກສາ', 'ຜູ້', 'ເຂົ້າ', 'ການຈັດຕັ້ງ', 'ສຶກສາ', 'ການຮຽນ', 'ການສອນ', 'ໄລຍະ', 'ການສຶກສາ', 'ເວລາ', 'ເນື້ອໃນ', 'ໂຄງສ້າງ', 'ຂອງ', 'ຫຼັກສູດ', 'ການກຳນົດ', 'ເຂົ້າໃນ', 'ຫຼັກສູດ', 'ແບ່ງ', 'ລາຍ', 'ວິຊາ', 'ຮຽນ', 'ໃນ', 'ແຕ່ລະ', 'ໝວດ', 'ວິຊາ', 'ການຮຽນ', 'ແຜນ', 'ການສອນ', 'ໃນ', 'ພາກ', 'ແຕ່ລະ', 'ຮຽນ', 'ແລະ', 'ແຕ່ລະ', 'ປີ', 'ເນື້ອໃນ', 'ຫຍໍ້', 'ຂອງ', 'ລາຍ', 'ການລົງທະບຽນ', 'ວິຊາ', 'ຮຽນ', 'ການວັດ', 'ຂໍ້ກຳນົດ', 'ການປະເມີນຜົນ', 'ການຮຽນ', 'ແລະ', 'ສຳເລັດ', 'ການສຶກສາ', 'ການວັດ', 'ຂໍ້ກຳນົດ', 'ຜົນ', 'ການຮຽນ', 'ການປະເມີນຜົນ', 'ຂໍ້ກຳນົດ', 'ການຮຽນ', 
# ...

# %%
from collections import Counter
c = Counter(words)
print(len(c),c)
# Out:
# 889 Counter({'ແລະ': 127, 'ວິຊາ': 109, 'ທີ່': 103, 'ໃນ': 74, 'ຂໍ້ມູນ': 68, 'ຮຽນ': 67, 'ມີ': 63, 'ໄດ້': 61, 'ຂອງ': 61, 'ນັກສຶກສາ': 58, 'ວິທະຍາສາດ': 51, 'ຄອມພິວເຕີ': 51, 'ຈະ': 49, 'ຫຼັກສູດ': 45, 'ເປັນ': 39, 'ທາງ': 31, 'ນີ້': 31, 'ຕ້ອງ': 31, 'ແບບ': 30, 'ວິທີ': 27, 'ລະບົບ': 27, 'ຜົນ': 26, 'ການສຶກສາ': 25, 'ເພື່ອ': 25, 'ພາກ': 23, 'ຄົນ': 23, 'ສາມາດ': 22, 'ໃຫ້': 22, 'ຊື່': 21, 'ການຮຽນ': 21, 'ລາຍ': 21, 'ໝວດ': 21, 'ຕາມ': 21, 'ບໍ່': 21, 'ວິທະຍານິພົນ': 21, 'ດ້ານ': 20, 'ລວມ': 19, 'ການຄົ້ນຄວ້າ': 18, 'ສຶກສາ': 17, 'ປີ': 17, 'ກ່ຽວກັບ': 16, 'ລາຍລະອຽດ': 16, 'ບັງຄັບ': 16, 'ຄະນະ': 15, 'ຈຳນວນ': 15, 'ຈາກ': 15, 'ແມ່ນ': 15, 'ກ່ອນ': 15, 'ຫຼື': 14, 'ນັ້ນ': 14, 'ສອນ': 13, 'ໂຄງສ້າງ': 13, 'ຮັບ': 13, 'ຂໍ້ກຳນົດ': 12, 'ສາຂາ': 12, 'ລະດັບ': 12, 'ຂັ້ນຕອນ': 12, 'ວ່າ': 12, 'ເລືອກ': 12, 'ລະຫັດ': 12, 'ສຳເລັດ': 11, 'ຜູ້': 11, 'ການປະເມີນຜົນ': 11, 'ໂທ': 11, 'ບັນຫາ': 11, 'Data': 11, 'ປະດິດ': 11, 'ໄປ': 11, 'ທີ': 11, 'ຕ່າງໆ': 11, 'ລົງທະບຽນ': 11, 'ຮັບຜິດຊອບ': 10, 'ການສອນ': 10, 'ຄວາມຮູ້': 10, 'ມາ': 10, 'ດ້ວຍ': 10, 'ລຳດັບ': 10, 'ຕົວ
# ...

# %%
c = sorted(c)
print(c)
# Out:
# ['A', 'AI', 'Advanced', 'Agent', 'Algorithm', 'Algorithms', 'Analytic', 'Artificial', 'B', 'B+', 'Bayesian', 'Big', 'Blockchain', 'C', 'C+', 'CGPA', 'CPU', 'Cloud', 'Compulsory', 'Computer', 'Computing', 'Courses', 'Cyber', 'D', 'D+', 'DSS', 'DVM', 'DVT', 'Data', 'Database', 'Decision', 'Development', 'Dynamic', 'Elective', 'Evaluation', 'Excellent', 'Experiment', 'F', 'Fail', 'Fair', 'Fairly', 'Full', 'Geometrical', 'Good', 'Graph', 'Hardware', 'IaaS', 'Infrastructure', 'Input', 'Intelligence', 'Internet', 'IoT', 'Learning', 'Letter', 'M.Sc.CS', 'Machine', 'Markov', 'Master', 'Methodology', 'Midterm', 'Miner', 'Mining', 'Motivation', 'No', 'Number', 'OLAP', 'OSS', 'Open', 'Operating', 'Output', 'PaaS', 'Platform', 'Poor', 'Program', 'Project', 'Python', 'R', 'Rapid', 'Research', 'SQL', 'SaaS', 'Science', 'Searching', 'Security', 'Semi', 'Service', 'Software', 'Sorting', 'Source', 'Stack', 'Startup', 'Structured', 'Structures', 'Support', 'System', 'Systems', 'Technology', 'Text', 'T
# ...

# %%
file_name = "corpus.txt"

existing_items = set()

# Read existing items from the file
try:
    with open(file_name, 'r', encoding='utf-8') as file:
        for line in file:
            # Remove newline characters and add to the set
            existing_items.add(line.strip())
except FileNotFoundError:
    # If the file does not exist, continue as there are no existing items
    pass

with open(file_name, 'a', encoding='utf-8') as file:
    for word in c:
        if word not in existing_items:
            file.write(word + '\n')
            existing_items.add(word)  

print("save successfully")
# Out:
# save successfully
