# %%
from laonlp import word_tokenize
import re

# %%
filename = 'Data/bachelor_web.txt'
cleaned_file = 'Cleaned_Data/cleaned_bachelor_web.txt'

# %% [markdown]
# # Clean Data

# %%
def remove_special_characters(filename, cleanded_file):
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

    pattern = r'[^a-zA-Zກຂຄງຈສຊຍດຕຖທນບປຜຝພຟມຢລຫຼຣວຫອຮໜໝໆຽະາ ິ ີ ຶ ື ໂ ໍເແ ຸ ູຳໄໃ ັ ົ ່ ້ ໌]'
    clean_text = re.sub(pattern, '', text)

    with open(cleanded_file, 'w', encoding='utf-8') as file:
        file.write(clean_text)

remove_special_characters(filename, cleaned_file)


def delete_space(cleaned_file):
    with open(cleaned_file, 'r',encoding='utf-8') as file:
        content = file.read()

    modifile_content = content.replace(" ", "")        

    with open(cleaned_file, 'w', encoding='utf-8') as file:
        file.write(modifile_content)
        
delete_space(cleaned_file)

# %%
def delete_text_from_file(cleaned_file, text_to_delete):
    with open(cleaned_file, 'r',encoding='utf-8') as file:
        content = file.read()

    modified_content = content.replace(text_to_delete, '')

    with open(cleaned_file, 'w', encoding='utf-8') as file:
        file.write(modified_content)

text_to_delete = "LSລາວສຶກສາຄວາມຮູ້ທົ່ວໄປESພາສາອັງກິດສຳລັບວິທະຍາສາດຄວາມຮູ້ທົ່ວໄປPYຈິດຕະວິທະຍາທົ່ວໄປຄວາມຮູ້ທົ່ວໄປCSລະບົບຄອມພິວເຕີພື້ນຖານວິຊາສະເພາະBCການນຳໃຊ້ຊອບແວພື້ນຖານພື້ນຖານວິຊາສະເພາະJAໂປຣແກຣມມິງJAVAວິຊາສະເພາະDBຄວາມຮູ້ພື້ນຖານກ່ຽວກັບຖານຂໍ້ມູນMsAccessວິຊາສະເພາະMCຄະນິດສາດສຳລັບຄອມພິວເຕີພື້ນຖານວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາLSລາວສຶກສາຄວາມຮູ້ທົ່ວໄປESພາສາອັງກິດສຳລັບວິທະຍາສາດຄວາມຮູ້ທົ່ວໄປMCຄະນິດສາດສຳລັບຄອມພິວເຕີພື້ນຖານວິຊາສະເພາະWPພື້ນຖານເວບໂປຣແກຣມມິງວິຊາສະເພາະCNການສື່ສານຂໍ້ມູນແລະເຄືອຂ່າຍວິຊາສະເພາະDSລະບົບຖານຂໍ້ມູນDatabaseSystemsວິຊາສະເພາະWMການອອກແບບເວັບໄຊວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາECພາສາອັງກິດສຳລັບຄອມພິວເຕີຄວາມຮູ້ທົ່ວໄປOSລະບົບປະຕິບັດການພື້ນຖານວິຊາສະເພາະDAໂຄງສ້າງຂອງຂໍ້ມູນແລະຂຶ້ນຕອນວິທີສຳລັບການພັດທະນາເວັບໄຊພື້ນຖານວິຊາສະເພາະITເຕັກໂນໂລຊີຂ່າວສານວິຊາສະເພາະJSການພັດທະນາເວັບໄຊດ້ວຍພາສາJSPວິຊາສະເພາະCGຄອມພິວເຕີກຣາຟິກWebGLວິຊາສະເພາະPHການພັດທະນາເວບໄຊດ້ວຍພາສາPHPວິຊາສະເພາະMBການຂຽນໂປຣແກຣມໃນມືຖືພື້ນຖານວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາWPການພັດທະນາເວັບໄຊດ້ວຍພາສາJSPframeworkວິຊາສະເພາະDAໂຄງສ້າງຂອງຂໍ້ມູນແລະຂຶ້ນຕອນວິທີສຳລັບການພັດທະນາເວັບໄຊພື້ນຖານວິຊາສະເພາະMIລະບົບຂ່າວສານເພື່ອການບໍລິຫານວິຊາສະເພາະHMHybridMobileAppວິຊາສະເພາະNDສຶກສາປ້ອງກັນຕົວຄວາມຮູ້ທົ່ວໄປAPການບຳລຸງຮັກສາແລະແກ້ໄຂບັນຫາຄອມພິວເຕີCompTIAAວິຊາສະເພາະSRສະຖິຕິວິໄຈພື້ນຖານວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາRMວິທີການຄົ້ນຄວ້າວິທະຍາສາດຄອມພິວເຕີພື້ນຖານວິຊາສະເພາະSAການບໍລິຫານເຄື່ອງແມ່ຂ່າຍວິຊາສະເພາະPHການພັດທະນາເວັບໄຊດ້ວຍພາສາPHPFrameworkວິຊາສະເພາະASການພັດທະນາເວັບໄຊດ້ວຍພາສາASPnetວິຊາສະເພາະECພາສາອັງກິດສຳລັບຄອມພິວເຕີຄວາມຮູ້ທົ່ວໄປEMການຄ້າດ້ວຍເອເລັກໂຕຣນິກECommerceວິຊາສະເພາະWTເວັບເຊີເວີແລະເວບເຕັກໂນໂລຊີWebServerandTechnologyວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາHRມະນຸດສຳພັນຄວາມຮູ້ທົ່ວໄປSCສຳມະນາພື້ນຖານວິຊາສະເພາະSEວິສະວະກຳຊັອບແວພື້ນຖານວິຊາສະເພາະMLມາຊີນເລີນນິ່ງMachineLearningພື້ນຖານວິຊາສະເພາະWSຄວາມປອດໄພຂອງເວັບໄຊວິຊາສະເພາະASການພັດທະນາເວັບໄຊດ້ວຍພາສາASPnetframeworkວິຊາສະເພາະMBການຂຽນໂປຣແກຣມໃນມືຖືພື້ນຖານວິຊາສະເພາະxxxxxxxxxxxxxxxxxxxxວິຊາເລືອກລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາPOການເມືອງPoliticsຄວາມຮູ້ທົ່ວໄປSCສຳມະນາພື້ນຖານວິຊາສະເພາະECພາສາອັງກິດສຳລັບຄອມພິວເຕີຄວາມຮູ້ທົ່ວໄປSIຍຸດທະສາດໃນການວາງແຜນລະບົບຂ່າວສານວິຊາສະເພາະAIປັນຍາປະດິດArtificialIntelligenceພື້ນຖານວິຊາສະເພາະASການນຳໃຊ້ຊອບແວຂັ້ນສູງMOSພື້ນຖານວິຊາສະເພາະSAການວິເຄາະແລະການອອກແບບລະບົບວິຊາສະເພາະDMDataMiningວິຊາສະເພາະລວມປີທີພາກຮຽນທີລະຫັດວິຊາຊື່ວິຊາຈຳນວນໜ່ວຍກິດໝວດວິຊາFPໂຄງການຈົບຊັ້ນວິຊາສະເພາະIPຝຶກງານຫຼືເຮັດໂຄງການຂະໜາດນ້ອຍວິຊາສະເພາະລວມ"
delete_text_from_file(cleaned_file, text_to_delete)

# %% [markdown]
# # Word Tokenize

# %%
with open(cleaned_file, encoding='utf-8') as file:
    content = file.read()
    words = word_tokenize(content)
print(len(words), words)
# Out:
# 925 ['ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', 'ຊື່', 'ຫຼັກສູດ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', 'BachelorofSciencePrograminWebApplicationDevelopment', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', 'ປຕວ', 'ການພັດທະນາ', 'ເວັບໄຊ', 'BachelorofScienceinWebApplicationDevelopmentBScWebDevelopment', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ວິທະຍາສາດທຳມະຊາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂທລະສັບ', 'ອີເມວ', 'csfnsnuoledula', 'ປັດຊະຍາ', 'ເພື່ອ', 'ປະຕິບັດ', 'ຕາມ', 'ແຜນ', 'ຍຸດທະສາດ', 'ການພັດທະນາການສຶກສາ', 'ຂອງ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂດຍສະເພາະ', 'ແມ່ນ', 'ການ', 'ບຸກ', 'ທະລຸ', 'ທາງ', 'ດ້ານ', 'ການພັດທະນາ', 'ຊັບພະຍາກອນ', 'ມະນຸດ', 'ແລະ', 'ການພັດທະນາ', 'ໃຫ້', 'ເປັນ', 'ສູນກາງ', 'ການສຶກສາ', 'ທີ່ມີຄຸນນະພາບ', 'ໃຫ້', 'ປະກົດ', 'ຜົນ', 'ເປັນ', 'ຈິງ', 'ການປັບປຸງ', 'ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ສາຂາການພັດທະນາ', 'ເວັບໄຊ', 'ໃຫ້ມີຄຸນນະພາບ', 'ແລະ', 'ສອດຄ່ອງ', 'ກັບ', 'ຄວາມຕ້ອງການ', 'ຂອງ', 
# ...

# %% [markdown]
# # Re-Cleaned Data

# %%
split_values = ['BachelorofSciencePrograminWebApplicationDevelopment',
                'BachelorofScienceinWebApplicationDevelopmentBScWebDevelopment','csfnsnuoledula',
                'HybridMobileApp','LaoAsiaTelecom','ສາຂາການພັດທະນາ','ປຕວ','ວິທະຍາສາດທຳມະຊາດ','ການພັດທະນາການສຶກສາ',
                'ທີ່ມີຄຸນນະພາບ','ໃຫ້ມີຄຸນນະພາບ','ນັກວິຊາການທີ່ມີ','ພາຍໃນປະເທດ','ໃຫ້ມີ','ສາຂາວິຊາ','ສາຂານີ້','ແລ້ວນັກສຶກສາ',
                'ເຂົ້າມານຳໃຊ້','ເພື່ອນຳມາ','ດຳເນີນການພັດທະນາ','ໂຄງການປ້ອງກັນ','ຫວັງດີດ້ວຍ','ວິທີການຮັກສາ','ຕະຫຼອດຊີວິດ',
                'ອອກຮັບໃຊ້','ທັດສະນະການເມືອງ','ແລ້ວຈະ','ບໍລິສັດທີ່','ທີ່ເຮັດວຽກ','ທີ່ມີການນຳໃຊ້','ການກຳນົດການເປີດ','ປີການສຶກສາ',
                'ສາຂາວິທະຍາສາດ','ທີ່ມີ','ທີ່ຈະ','ທີ່ມີມາດຖານ','ຖືກຕ້ອງຕາມ','ກຳນົດໄວ້','ຄະນະກຳມະການສອບເສັງ','ກະຊວງສຶກສາທິການ',
                'ແຕ່ລະພາກ','ກິດການກຳນົດການຈັດຕັ້ງ','ແຮວັນ','ເວລາການສຶກສານັກສຶກສາ','ແຜນການຮຽນ','ຮັກສາວັດທະນະທຳ']

items_to_insert = [['Bachelor', 'of','Science','Program','in','Web','Application','Development'],
                   ['Bachelor', 'of','Science','in','Web','Application','Development','B.Sc.','Web','Development'],
                   ['cs.fns@nuol.edu.la'],['Hybrid','Mobile','App'],['Lao','Asia','Telecom'],['ສາຂາ','ການພັດທະນາ'],
                   ['ປຕ.ວ.'],['ວິທະຍາສາດ','ທຳມະຊາດ'],['ການພັດທະນາ','ການສຶກສາ'],['ທີ່','ມີ','ຄຸນນະພາບ'],
                   ['ໃຫ້','ມີ','ຄຸນນະພາບ'],['ນັກວິຊາການ','ທີ່','ມີ'],['ພາຍໃນ','ປະເທດ'],['ໃຫ້','ມີ'],['ສາຂາ','ວິຊາ'],
                   ['ສາຂາ','ນີ້'],['ແລ້ວ','ນັກສຶກສາ'],['ເຂົ້າມາ','ນຳໃຊ້'],['ເພື່ອ','ນຳມາ'],['ດຳເນີນ','ການພັດທະນາ'],
                   ['ໂຄງການ','ປ້ອງກັນ'],['ຫວັງດີ','ດ້ວຍ'],['ວິທີ','ການຮັກສາ'],['ຕະຫຼອດ','ຊີວິດ'],['ອອກ','ຮັບໃຊ້'],
                   ['ທັດສະນະ','ການເມືອງ'],['ແລ້ວ','ຈະ'],['ບໍລິສັດ','ທີ່'],['ທີ່','ເຮັດວຽກ'],['ທີ່','ມີ','ການນຳໃຊ້'],
                   ['ການກຳນົດ','ການເປີດ'],['ປີ','ການສຶກສາ'],['ສາຂາ','ວິທະຍາສາດ'],['ທີ່','ມີ'],['ທີ່','ຈະ'],['ທີ່','ມີ','ມາດຖານ'],
                   ['ຖືກຕ້ອງ','ຕາມ'],['ກຳນົດ','ໄວ້'],['ຄະນະ','ກຳມະການ','ສອບເສັງ'],['ກະຊວງ','ສຶກສາທິການ'],['ແຕ່ລະ','ພາກ'],
                   ['ກິດ','ການກຳນົດ','ການຈັດຕັ້ງ'],['ແຮ','ວັນ'],['ເວລາ','ການສຶກສາ','ນັກສຶກສາ'],['ແຜນ','ການຮຽນ'],
                   ['ຮັກສາ','ວັດທະນະທຳ']]

for split_value, items in zip(split_values, items_to_insert):
    index = 0
    while index < len(words):
        if words[index] == split_value:
            # Insert the items after the split value
            for item in items:
                words.insert(index + 1, item)
            # Move index past the newly inserted items
            index += len(items)
            words.remove(split_value)
        else:
            index += 1

print(len(words), words)
# Out:
# 1011 ['ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'ຊື່', 'ຫຼັກສູດ', 'ຫຼັກສູດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'Development', 'Application', 'Web', 'in', 'Program', 'Science', 'of', 'Bachelor', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ປະລິນຍາ', 'ຕີ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'ປຕ.ວ.', 'ການພັດທະນາ', 'ເວັບໄຊ', 'Development', 'Web', 'B.Sc.', 'Development', 'Application', 'Web', 'in', 'Science', 'of', 'Bachelor', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ພາກ', 'ວິຊາວິທະຍາສາດ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ທຳມະຊາດ', 'ວິທະຍາສາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂທລະສັບ', 'ອີເມວ', 'cs.fns@nuol.edu.la', 'ປັດຊະຍາ', 'ເພື່ອ', 'ປະຕິບັດ', 'ຕາມ', 'ແຜນ', 'ຍຸດທະສາດ', 'ການສຶກສາ', 'ການພັດທະນາ', 'ຂອງ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂດຍສະເພາະ', 'ແມ່ນ', 'ການ', 'ບຸກ', 'ທະລຸ', 'ທາງ', 'ດ້ານ', 'ການພັດທະນາ', 'ຊັບພະຍາກອນ', 'ມະນຸດ', 'ແລະ', 'ການພັດທະນາ', 'ໃຫ້', 'ເປັນ', 'ສູນກາງ', 'ການສຶກສາ', 'ຄຸນນະພາບ', 'ມີ', 'ທີ່', 'ໃຫ້', 'ປະກົດ', 'ຜົນ', 'ເປັນ', 'ຈິງ', 'ການປັບປຸງ', 'ຫຼັກສູດ', 'ວິທ
# ...

# %%
items_to_remove = ['ປະລິນຍາ','ຕີ','ວິຊາວິທະຍາສາດ','ການ','ບຸກ','ທະລຸ','ຈິງ','ຫຼັກ','ມູນ','ໆ','ເຟັ້ນ','ການນຳ','ເອ', 'ເລັກ','ຣ',
                   'ນິກ','ເຄື່ອ','ຂ່າຍ','ຄວາມ','ຈົງຮັກພັກດີ','ທິກ','ໂກ້','ໆ','ສົກ','ຄາດຄະເນນ','ສ','ຕອນ','ນຳ','ສົ່ງ',
                   'ໂກ','ຕາ','ກົມ','ກອງ','ໜ່ວຍ','ກິດ']
items_to_add = ['ປະລິນຍາຕີ','ພາກວິຊາ','ວິທະຍາສາດ','ການບຸກທະລຸ','ເປັນຈິງ','ຫຼັກມູນ','ຜູ້ຮຽນ','ອື່ນໆ','ເລືອກເຟັ້ນ','ການນຳສະເໜີ',
                'ເອເລັກໂທຣນິກ','ເຄືອຂ່າຍ','ຄວາມຮຽກຮ້ອງ','ຄວາມຈົງຮັກພັກດີ','ດັ່ງນີ້','ທິກໂກ້', 'ອື່ນໆ', 'ສົກຮຽນ','ຄາດຄະເນ',
                'ຕອນປາຍ','ໃບນຳສົ່ງ','ໂກຕາ','ກົມກອງ','ໜ່ວຍກິດ','ພາກຮຽນ']

words = [item for item in words if item not in items_to_remove]
words.extend(items_to_add)
print(len(words), words)
# Out:
# 966 ['ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'ຊື່', 'ຫຼັກສູດ', 'ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'Development', 'Application', 'Web', 'in', 'Program', 'Science', 'of', 'Bachelor', 'ຊື່', 'ປະກາສະນີຍະບັດ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'ປຕ.ວ.', 'ການພັດທະນາ', 'ເວັບໄຊ', 'Development', 'Web', 'B.Sc.', 'Development', 'Application', 'Web', 'in', 'Science', 'of', 'Bachelor', 'ໜ່ວຍງານ', 'ຮັບຜິດຊອບ', 'ພາກ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ທຳມະຊາດ', 'ວິທະຍາສາດ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂທລະສັບ', 'ອີເມວ', 'cs.fns@nuol.edu.la', 'ປັດຊະຍາ', 'ເພື່ອ', 'ປະຕິບັດ', 'ຕາມ', 'ແຜນ', 'ຍຸດທະສາດ', 'ການສຶກສາ', 'ການພັດທະນາ', 'ຂອງ', 'ມະຫາວິທະຍາໄລ', 'ແຫ່ງຊາດ', 'ໂດຍສະເພາະ', 'ແມ່ນ', 'ທາງ', 'ດ້ານ', 'ການພັດທະນາ', 'ຊັບພະຍາກອນ', 'ມະນຸດ', 'ແລະ', 'ການພັດທະນາ', 'ໃຫ້', 'ເປັນ', 'ສູນກາງ', 'ການສຶກສາ', 'ຄຸນນະພາບ', 'ມີ', 'ທີ່', 'ໃຫ້', 'ປະກົດ', 'ຜົນ', 'ເປັນ', 'ການປັບປຸງ', 'ຫຼັກສູດ', 'ວິທະຍາສາດ', 'ການພັດທະນາ', 'ສາຂາ', 'ເວັບໄຊ', 'ຄຸນນະພາບ', 'ມີ', 'ໃຫ້', 'ແລະ', 'ສອດຄ່ອງ', 'ກັບ', 'ຄວາມຕ້
# ...

# %% [markdown]
# # Save to Lao Corpus

# %%
from collections import Counter
c = Counter(words)
print(len(c),c)
# Out:
# 344 Counter({'ມີ': 30, 'ເວັບໄຊ': 26, 'ແລະ': 25, 'ໃນ': 25, 'ຮຽນ': 22, 'ທີ່': 21, 'ການພັດທະນາ': 18, 'ຂອງ': 15, 'ເພື່ອ': 12, 'ໃຫ້': 12, 'ໂມງ': 12, 'ຫຼັກສູດ': 11, 'ຕາມ': 11, 'ເປັນ': 11, 'ຕ່າງໆ': 11, 'ຫຼື': 11, 'ພາກ': 10, 'ການສຶກສາ': 10, 'ຜູ້': 10, 'ໄດ້': 10, 'ວິຊາ': 10, 'ສາຂາ': 9, 'ດ້ານ': 9, 'ປີ': 9, 'ນັກສຶກສາ': 8, 'ວິທະຍາສາດ': 7, 'ສັງຄົມ': 7, 'ສ້າງ': 7, 'ຢ່າງ': 7, 'ທັກສະ': 7, 'ທາງ': 6, 'ຄວາມຕ້ອງການ': 6, 'ການຮຽນ': 6, 'ຈະ': 6, 'ສາມາດ': 6, 'ແຕ່': 6, 'ອາທິດ': 6, 'ທີ': 6, 'ຄອມພິວເຕີ': 5, 'ນີ້': 5, 'ພັດທະນາ': 5, 'ອາຊີບ': 5, 'ບໍລິສັດ': 5, 'ບໍ່': 5, 'ຈົບ': 5, 'ຕ້ອງ': 5, 'ເວລາ': 5, 'ໄລຍະ': 5, 'ໝວດ': 5, 'ແຜນ': 4, 'ລະບົບ': 4, 'ໂດຍ': 4, 'ນຳໃຊ້': 4, 'ຄວາມສາມາດ': 4, 'ລະດັບ': 4, 'ຄວາມຮູ້': 4, 'ປະກອບ': 4, 'ອື່ນ': 4, 'ພື້ນຖານ': 4, 'ຕໍ່': 4, 'ພາຍຫຼັງ': 4, 'ສຳເລັດ': 4, 'ບັນຫາ': 4, 'ສຶກສາ': 4, 'ຈຳນວນ': 4, 'ຄັດເລືອກ': 4, 'ການສອນ': 4, 'ເກີນ': 4, 'ໜຶ່ງ': 4, 'ຫາ': 4, 'ຊື່': 3, 'Development': 3, 'Web': 3, 'ແມ່ນ': 3, 'ຜົນ': 3, 'ທັງ': 3, 'ຕະຫຼາດ': 3, 'ໂທລະຄົມມະນາຄົມ': 3, 'ລາວ': 3, 'ການຮຽນຮູ້': 3, 'ເລືອກ': 3, 'ຂໍ້
# ...

# %%
c = sorted(c)
print(c)
# Out:
# ['App', 'Application', 'Asia', 'B.Sc.', 'Bachelor', 'Development', 'Hybrid', 'Lao', 'Mobile', 'Program', 'Science', 'Telecom', 'Web', 'cs.fns@nuol.edu.la', 'in', 'of', 'ກວມເອົາ', 'ກະກຽມ', 'ກະຊວງ', 'ກັບ', 'ການກຳນົດ', 'ການກໍ່ສ້າງ', 'ການຄົ້ນຄິດ', 'ການຈັດຕັ້ງ', 'ການຕອບສະໜອງ', 'ການນຳສະເໜີ', 'ການນຳໃຊ້', 'ການບຸກທະລຸ', 'ການປະກອບ', 'ການປັບປຸງ', 'ການພັດທະນາ', 'ການວິເຄາະ', 'ການສອນ', 'ການສຶກສາ', 'ການສື່ສານ', 'ການສ້າງ', 'ການຮັກສາ', 'ການຮຽນ', 'ການຮຽນຮູ້', 'ການເປັນ', 'ການເປີດ', 'ການເມືອງ', 'ການເຮັດວຽກ', 'ການແກ້ໄຂ', 'ການໂຈມຕີ', 'ກຳນົດ', 'ກຳມະການ', 'ກິລາ', 'ກຸ່ມຄົນ', 'ກົມກອງ', 'ກ່ອນ', 'ກ່ຽວກັບ', 'ກ່ຽວຂ້ອງ', 'ຂອງ', 'ຂະຫຍາຍ', 'ຂັ້ນຕອນ', 'ຂໍ້', 'ຂໍ້ຕົກລົງ', 'ຂໍ້ມູນຂ່າວສານ', 'ຄວາມຈົງຮັກພັກດີ', 'ຄວາມຊື່ສັດ', 'ຄວາມຊ່ຽວຊານ', 'ຄວາມຕ້ອງການ', 'ຄວາມຖືກຕ້ອງ', 'ຄວາມປອດໄພ', 'ຄວາມພ້ອມ', 'ຄວາມສາມາດ', 'ຄວາມຮູ້', 'ຄວາມຮຽກຮ້ອງ', 'ຄວາມເໝາະສົມ', 'ຄອມພິວເຕີ', 'ຄະນະ', 'ຄັດເລືອກ', 'ຄາດຄະເນ', 'ຄຳຮ້ອງ', 'ຄຸນນະພາບ', 'ຄຸນສົມບັດ', 'ຄຸ້ມຄອງ', 'ຄູ', 'ຄູສອນ', 'ຄົບ', 'ຄ່ອງແຄ້ວ', 'ຈະ', 'ຈັນຍາບັນ', 'ຈາກ', 'ຈຳນວນ', 'ຈຸດປະສົງ', 'ຈົນ', '
# ...

# %%
file_name = "corpus.txt"

existing_items = set()

# Read existing items from the file
try:
    with open(file_name, 'r', encoding='utf-8') as file:
        for line in file:
            # Remove newline characters and add to the set
            existing_items.add(line.strip())
except FileNotFoundError:
    # If the file does not exist, continue as there are no existing items
    pass

with open(file_name, 'a', encoding='utf-8') as file:
    for word in c:
        if word not in existing_items:
            file.write(word + '\n')
            existing_items.add(word)  

print("save successfully")
# Out:
# save successfully
